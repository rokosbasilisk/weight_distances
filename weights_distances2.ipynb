# %% [markdown]
# # Weights Distances

# %%
######################## (70m) ############################

# %%
from tqdm import tqdm
from transformers import GPTNeoXForCausalLM, AutoTokenizer
import concurrent.futures
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pickle
import seaborn as sns



tokenizer = AutoTokenizer.from_pretrained( "EleutherAI/pythia-70m-deduped", revision="step143000" )
ref_model = GPTNeoXForCausalLM.from_pretrained( "EleutherAI/pythia-70m-deduped", revision="step143000")
ref_model_params = ref_model.state_dict()

# %%
# Define the function to calculate layer distances
def calculate_layer_distances(step_idx,rev_id):
    model = GPTNeoXForCausalLM.from_pretrained( "EleutherAI/pythia-70m-deduped", revision=rev_id)
    model_params = model.state_dict()
        
    layer_dists = {}
    
    for layer in list(model_params.keys()):
        # Extract weights for the current layer
        weights_model = model_params[layer]
        weights_ref_model = ref_model_params[layer]

        # Calculate Euclidean distance (you can replace this with other metrics)
        euclidean_distance = (weights_model - weights_ref_model).norm().item()
        layer_dists[layer] = euclidean_distance
        print(f"Step {rev_id} Layer {layer}: Euclidean Distance = {euclidean_distance}")

    del model
    return layer_dists

# %%
# Define the function to calculate layer distances
def calculate_layer_diff_rank(step_idx,rev_id):
    model = GPTNeoXForCausalLM.from_pretrained( "EleutherAI/pythia-70m-deduped", revision=rev_id)
    model_params = model.state_dict()
        
    rank_dict = {}
    
    for layer in list(model_params.keys()):
        # Extract weights for the current layer
        weights_model = model_params[layer]
        weights_ref_model = ref_model_params[layer]

        # Calculate Euclidean distance (you can replace this with other metrics)
        rank = np.linalg.matrix_rank(weights_ref_model.cpu().detach().numpy()-weights_model.cpu().detach().numpy())

        # Store the rank in the dictionary
        rank_dict[layer] = rank
        print(f"Step {rev_id} Layer {layer}: Rank = {rank}")

    del model
    return rank_dict

# %%
# Set the number of steps and the number of steps to process simultaneously
num_steps = 143  # Adjust this according to your actual number of steps

# %%
# since the distance is majorly in the first and last layers, should we apply layerwise learning rates ?3
# the overall "loss" is sum of individial layer-losses
# so, from the plots of layerwise distances it can be seen which layer has a steep-decrease in distance and which layer does'nt 
# this can be used for layerwise finetuning ?

# %%
weight_diff_ranks = {}

# Iterate over the steps without using ThreadPoolExecutor
for step_idx in tqdm(range(num_steps), total=num_steps):
    revision_id = f"step{1000*(step_idx+1)}"
    weight_diff_ranks[step_idx] = calculate_layer_diff_rank(step_idx, revision_id)
# Out:
#   0%|                                                                                                                                                                                      | 0/143 [00:00<?, ?it/s]
# Step step1000 Layer gpt_neox.embed_in.weight: Rank = 512
# Step step1000 Layer gpt_neox.layers.0.input_layernorm.weight: Rank = 1
# Step step1000 Layer gpt_neox.layers.0.input_layernorm.bias: Rank = 1
# Step step1000 Layer gpt_neox.layers.0.post_attention_layernorm.weight: Rank = 1
# Step step1000 Layer gpt_neox.layers.0.post_attention_layernorm.bias: Rank = 1
# Step step1000 Layer gpt_neox.layers.0.attention.query_key_value.weight: Rank = 512
# Step step1000 Layer gpt_neox.layers.0.attention.query_key_value.bias: Rank = 1
# Step step1000 Layer gpt_neox.layers.0.attention.dense.weight: Rank = 511
# Step step1000 Layer gpt_neox.layers.0.attention.dense.bias: Rank = 1
# Step step1000 Layer gpt_neox.layers.0.mlp.dense_h_to_4h.weight: Rank = 512
# Step step1000 Layer gpt_neox.layers.0.mlp.dense_h_to_4h.bias: Rank = 1
# Step step1000 Layer gpt_neox.layers.0.mlp.dense_4h_to_h.weight: Rank = 512
# Step step1000 Layer gpt_neox.layers.0.mlp.dense_4h_to_h.bias: Rank = 1
# Step step1000 Layer gpt_neox.layers.1.input_layernorm.weight: Rank = 1
# Step step1000 Layer gpt_neox.layers.1.input_layernorm.bias: Rank = 1
# Step step1000 Layer gpt_neox.layers.1.post_attention_layernorm.weight: Rank = 1
# Step step1000 Layer gpt_neox.layers.1.post_attention_layernorm.bias: Rank = 1
# Step step1000 Layer gpt_neox.layers.1.attention.query_key_value.weight: Rank = 512
# Step step1000 Layer gpt_neox.layers.1.attention.query_key_value.bias: Rank = 1
# Step step1000 Layer gpt_neox.layers.1.attention.dense.weight: Rank = 512
# Step step1000 Layer gpt_neox.layers.1.attention.dense.bias: Rank = 1
# Step step1000 Layer gpt_neox.layers.1.mlp.dense_h_to_4h.weight: Rank = 512
# Step step1000 Layer gpt_neox.layers.1.mlp.dense_h_to_4h.bias: Rank = 1
# Step step1000 Layer gpt_neox.layers.1.mlp.dense_4h_to_h.weight: Rank = 512
# Step step1000 Layer gpt_neox.layers.1.mlp.dense_4h_to_h.bias: Rank = 1
# Step step1000 Layer gpt_neox.layers.2.input_layernorm.weight: Rank = 1
# Step step1000 Layer gpt_neox.layers.2.input_layernorm.bias: Rank = 1
# Step step1000 Layer gpt_neox.layers.2.post_attention_layernorm.weight: Rank = 1
# Step step1000 Layer gpt_neox.layers.2.post_attention_layernorm.bias: Rank = 1
# Step step1000 Layer gpt_neox.layers.2.attention.query_key_value.weight: Rank = 512
# Step step1000 Layer gpt_neox.layers.2.attention.query_key_value.bias: Rank = 1
# Step step1000 Layer gpt_neox.layers.2.attention.dense.weight: Rank = 512
# Step step1000 Layer gpt_neox.layers.2.attention.dense.bias: Rank = 1
# Step step1000 Layer gpt_neox.layers.2.mlp.dense_h_to_4h.weight: Rank = 512
# Step step1000 Layer gpt_neox.layers.2.mlp.dense_h_to_4h.bias: Rank = 1
# Step step1000 Layer gpt_neox.layers.2.mlp.dense_4h_to_h.weight: Rank = 512
# Step step1000 Layer gpt_neox.layers.2.mlp.dense_4h_to_h.bias: Rank = 1
# Step step1000 Layer gpt_neox.layers.3.input_layernorm.weight: Rank = 1
# Step step1000 Layer gpt_neox.layers.3.input_layernorm.bias: Rank = 1
# Step step1000 Layer gpt_neox.layers.3.post_attention_layernorm.weight: Rank = 1
# Step step1000 Layer gpt_neox.layers.3.post_attention_layernorm.bias: Rank = 1
# Step step1000 Layer gpt_neox.layers.3.attention.query_key_value.weight: Rank = 512
# Step step1000 Layer gpt_neox.layers.3.attention.query_key_value.bias: Rank = 1
# Step step1000 Layer gpt_neox.layers.3.attention.dense.weight: Rank = 511
# Step step1000 Layer gpt_neox.layers.3.attention.dense.bias: Rank = 1
# Step step1000 Layer gpt_neox.layers.3.mlp.dense_h_to_4h.weight: Rank = 512
# Step step1000 Layer gpt_neox.layers.3.mlp.dense_h_to_4h.bias: Rank = 1
# Step step1000 Layer gpt_neox.layers.3.mlp.dense_4h_to_h.weight: Rank = 512
# Step step1000 Layer gpt_neox.layers.3.mlp.dense_4h_to_h.bias: Rank = 1
# Step step1000 Layer gpt_neox.layers.4.input_layernorm.weight: Rank = 1
# Step step1000 Layer gpt_neox.layers.4.input_layernorm.bias: Rank = 1
# Step step1000 Layer gpt_neox.layers.4.post_attention_layernorm.weight: Rank = 1
# Step step1000 Layer gpt_neox.layers.4.post_attention_layernorm.bias: Rank = 1
# Step step1000 Layer gpt_neox.layers.4.attention.query_key_value.weight: Rank = 512
# Step step1000 Layer gpt_neox.layers.4.attention.query_key_value.bias: Rank = 1
# Step step1000 Layer gpt_neox.layers.4.attention.dense.weight: Rank = 512
# Step step1000 Layer gpt_neox.layers.4.attention.dense.bias: Rank = 1
# Step step1000 Layer gpt_neox.layers.4.mlp.dense_h_to_4h.weight: Rank = 512
# Step step1000 Layer gpt_neox.layers.4.mlp.dense_h_to_4h.bias: Rank = 1
# Step step1000 Layer gpt_neox.layers.4.mlp.dense_4h_to_h.weight: Rank = 512
# Step step1000 Layer gpt_neox.layers.4.mlp.dense_4h_to_h.bias: Rank = 1
# Step step1000 Layer gpt_neox.layers.5.input_layernorm.weight: Rank = 1
# Step step1000 Layer gpt_neox.layers.5.input_layernorm.bias: Rank = 1
# Step step1000 Layer gpt_neox.layers.5.post_attention_layernorm.weight: Rank = 1
# Step step1000 Layer gpt_neox.layers.5.post_attention_layernorm.bias: Rank = 1
# Step step1000 Layer gpt_neox.layers.5.attention.query_key_value.weight: Rank = 512
# Step step1000 Layer gpt_neox.layers.5.attention.query_key_value.bias: Rank = 1
# Step step1000 Layer gpt_neox.layers.5.attention.dense.weight: Rank = 512
# Step step1000 Layer gpt_neox.layers.5.attention.dense.bias: Rank = 1
# Step step1000 Layer gpt_neox.layers.5.mlp.dense_h_to_4h.weight: Rank = 512
# Step step1000 Layer gpt_neox.layers.5.mlp.dense_h_to_4h.bias: Rank = 1
# Step step1000 Layer gpt_neox.layers.5.mlp.dense_4h_to_h.weight: Rank = 512
# Step step1000 Layer gpt_neox.layers.5.mlp.dense_4h_to_h.bias: Rank = 1
# Step step1000 Layer gpt_neox.final_layer_norm.weight: Rank = 1
# Step step1000 Layer gpt_neox.final_layer_norm.bias: Rank = 1
#   1%|█▏                                                                                                                                                                            | 1/143 [00:04<09:39,  4.08s/it]
# Step step1000 Layer embed_out.weight: Rank = 512
# Step step2000 Layer gpt_neox.embed_in.weight: Rank = 512
# Step step2000 Layer gpt_neox.layers.0.input_layernorm.weight: Rank = 1
# Step step2000 Layer gpt_neox.layers.0.input_layernorm.bias: Rank = 1
# Step step2000 Layer gpt_neox.layers.0.post_attention_layernorm.weight: Rank = 1
# Step step2000 Layer gpt_neox.layers.0.post_attention_layernorm.bias: Rank = 1
# Step step2000 Layer gpt_neox.layers.0.attention.query_key_value.weight: Rank = 512
# Step step2000 Layer gpt_neox.layers.0.attention.query_key_value.bias: Rank = 1
# Step step2000 Layer gpt_neox.layers.0.attention.dense.weight: Rank = 511
# Step step2000 Layer gpt_neox.layers.0.attention.dense.bias: Rank = 1
# Step step2000 Layer gpt_neox.layers.0.mlp.dense_h_to_4h.weight: Rank = 512
# Step step2000 Layer gpt_neox.layers.0.mlp.dense_h_to_4h.bias: Rank = 1
# Step step2000 Layer gpt_neox.layers.0.mlp.dense_4h_to_h.weight: Rank = 512
# Step step2000 Layer gpt_neox.layers.0.mlp.dense_4h_to_h.bias: Rank = 1
# Step step2000 Layer gpt_neox.layers.1.input_layernorm.weight: Rank = 1
# Step step2000 Layer gpt_neox.layers.1.input_layernorm.bias: Rank = 1
# Step step2000 Layer gpt_neox.layers.1.post_attention_layernorm.weight: Rank = 1
# Step step2000 Layer gpt_neox.layers.1.post_attention_layernorm.bias: Rank = 1
# Step step2000 Layer gpt_neox.layers.1.attention.query_key_value.weight: Rank = 512
# Step step2000 Layer gpt_neox.layers.1.attention.query_key_value.bias: Rank = 1
# Step step2000 Layer gpt_neox.layers.1.attention.dense.weight: Rank = 512
# Step step2000 Layer gpt_neox.layers.1.attention.dense.bias: Rank = 1
# Step step2000 Layer gpt_neox.layers.1.mlp.dense_h_to_4h.weight: Rank = 512
# Step step2000 Layer gpt_neox.layers.1.mlp.dense_h_to_4h.bias: Rank = 1
# Step step2000 Layer gpt_neox.layers.1.mlp.dense_4h_to_h.weight: Rank = 512
# Step step2000 Layer gpt_neox.layers.1.mlp.dense_4h_to_h.bias: Rank = 1
# Step step2000 Layer gpt_neox.layers.2.input_layernorm.weight: Rank = 1
# Step step2000 Layer gpt_neox.layers.2.input_layernorm.bias: Rank = 1
# Step step2000 Layer gpt_neox.layers.2.post_attention_layernorm.weight: Rank = 1
# Step step2000 Layer gpt_neox.layers.2.post_attention_layernorm.bias: Rank = 1
# Step step2000 Layer gpt_neox.layers.2.attention.query_key_value.weight: Rank = 512
# Step step2000 Layer gpt_neox.layers.2.attention.query_key_value.bias: Rank = 1
# Step step2000 Layer gpt_neox.layers.2.attention.dense.weight: Rank = 512
# Step step2000 Layer gpt_neox.layers.2.attention.dense.bias: Rank = 1
# Step step2000 Layer gpt_neox.layers.2.mlp.dense_h_to_4h.weight: Rank = 512
# Step step2000 Layer gpt_neox.layers.2.mlp.dense_h_to_4h.bias: Rank = 1
# Step step2000 Layer gpt_neox.layers.2.mlp.dense_4h_to_h.weight: Rank = 512
# Step step2000 Layer gpt_neox.layers.2.mlp.dense_4h_to_h.bias: Rank = 1
# Step step2000 Layer gpt_neox.layers.3.input_layernorm.weight: Rank = 1
# Step step2000 Layer gpt_neox.layers.3.input_layernorm.bias: Rank = 1
# Step step2000 Layer gpt_neox.layers.3.post_attention_layernorm.weight: Rank = 1
# Step step2000 Layer gpt_neox.layers.3.post_attention_layernorm.bias: Rank = 1
# Step step2000 Layer gpt_neox.layers.3.attention.query_key_value.weight: Rank = 512
# Step step2000 Layer gpt_neox.layers.3.attention.query_key_value.bias: Rank = 1
# Step step2000 Layer gpt_neox.layers.3.attention.dense.weight: Rank = 511
# Step step2000 Layer gpt_neox.layers.3.attention.dense.bias: Rank = 1
# Step step2000 Layer gpt_neox.layers.3.mlp.dense_h_to_4h.weight: Rank = 512
# Step step2000 Layer gpt_neox.layers.3.mlp.dense_h_to_4h.bias: Rank = 1
# Step step2000 Layer gpt_neox.layers.3.mlp.dense_4h_to_h.weight: Rank = 512
# Step step2000 Layer gpt_neox.layers.3.mlp.dense_4h_to_h.bias: Rank = 1
# Step step2000 Layer gpt_neox.layers.4.input_layernorm.weight: Rank = 1
# Step step2000 Layer gpt_neox.layers.4.input_layernorm.bias: Rank = 1
# Step step2000 Layer gpt_neox.layers.4.post_attention_layernorm.weight: Rank = 1
# Step step2000 Layer gpt_neox.layers.4.post_attention_layernorm.bias: Rank = 1
# Step step2000 Layer gpt_neox.layers.4.attention.query_key_value.weight: Rank = 512
# Step step2000 Layer gpt_neox.layers.4.attention.query_key_value.bias: Rank = 1
# Step step2000 Layer gpt_neox.layers.4.attention.dense.weight: Rank = 511
# Step step2000 Layer gpt_neox.layers.4.attention.dense.bias: Rank = 1
# Step step2000 Layer gpt_neox.layers.4.mlp.dense_h_to_4h.weight: Rank = 512
# Step step2000 Layer gpt_neox.layers.4.mlp.dense_h_to_4h.bias: Rank = 1
# Step step2000 Layer gpt_neox.layers.4.mlp.dense_4h_to_h.weight: Rank = 512
# Step step2000 Layer gpt_neox.layers.4.mlp.dense_4h_to_h.bias: Rank = 1
# Step step2000 Layer gpt_neox.layers.5.input_layernorm.weight: Rank = 1
# Step step2000 Layer gpt_neox.layers.5.input_layernorm.bias: Rank = 1
# Step step2000 Layer gpt_neox.layers.5.post_attention_layernorm.weight: Rank = 1
# Step step2000 Layer gpt_neox.layers.5.post_attention_layernorm.bias: Rank = 1
# Step step2000 Layer gpt_neox.layers.5.attention.query_key_value.weight: Rank = 512
# Step step2000 Layer gpt_neox.layers.5.attention.query_key_value.bias: Rank = 1
# Step step2000 Layer gpt_neox.layers.5.attention.dense.weight: Rank = 512
# Step step2000 Layer gpt_neox.layers.5.attention.dense.bias: Rank = 1
# Step step2000 Layer gpt_neox.layers.5.mlp.dense_h_to_4h.weight: Rank = 512
# Step step2000 Layer gpt_neox.layers.5.mlp.dense_h_to_4h.bias: Rank = 1
# Step step2000 Layer gpt_neox.layers.5.mlp.dense_4h_to_h.weight: Rank = 512
# Step step2000 Layer gpt_neox.layers.5.mlp.dense_4h_to_h.bias: Rank = 1
# Step step2000 Layer gpt_neox.final_layer_norm.weight: Rank = 1
# Step step2000 Layer gpt_neox.final_layer_norm.bias: Rank = 1
#   1%|██▍                                                                                                                                                                           | 2/143 [00:08<10:07,  4.31s/it]
# Step step2000 Layer embed_out.weight: Rank = 512
# Step step3000 Layer gpt_neox.embed_in.weight: Rank = 512
# Step step3000 Layer gpt_neox.layers.0.input_layernorm.weight: Rank = 1
# Step step3000 Layer gpt_neox.layers.0.input_layernorm.bias: Rank = 1
# Step step3000 Layer gpt_neox.layers.0.post_attention_layernorm.weight: Rank = 1
# Step step3000 Layer gpt_neox.layers.0.post_attention_layernorm.bias: Rank = 1
# Step step3000 Layer gpt_neox.layers.0.attention.query_key_value.weight: Rank = 512
# Step step3000 Layer gpt_neox.layers.0.attention.query_key_value.bias: Rank = 1
# Step step3000 Layer gpt_neox.layers.0.attention.dense.weight: Rank = 512
# Step step3000 Layer gpt_neox.layers.0.attention.dense.bias: Rank = 1
# Step step3000 Layer gpt_neox.layers.0.mlp.dense_h_to_4h.weight: Rank = 512
# Step step3000 Layer gpt_neox.layers.0.mlp.dense_h_to_4h.bias: Rank = 1
# Step step3000 Layer gpt_neox.layers.0.mlp.dense_4h_to_h.weight: Rank = 512
# Step step3000 Layer gpt_neox.layers.0.mlp.dense_4h_to_h.bias: Rank = 1
# Step step3000 Layer gpt_neox.layers.1.input_layernorm.weight: Rank = 1
# Step step3000 Layer gpt_neox.layers.1.input_layernorm.bias: Rank = 1
# Step step3000 Layer gpt_neox.layers.1.post_attention_layernorm.weight: Rank = 1
# Step step3000 Layer gpt_neox.layers.1.post_attention_layernorm.bias: Rank = 1
# Step step3000 Layer gpt_neox.layers.1.attention.query_key_value.weight: Rank = 512
# Step step3000 Layer gpt_neox.layers.1.attention.query_key_value.bias: Rank = 1
# Step step3000 Layer gpt_neox.layers.1.attention.dense.weight: Rank = 512
# Step step3000 Layer gpt_neox.layers.1.attention.dense.bias: Rank = 1
# Step step3000 Layer gpt_neox.layers.1.mlp.dense_h_to_4h.weight: Rank = 512
# Step step3000 Layer gpt_neox.layers.1.mlp.dense_h_to_4h.bias: Rank = 1
# Step step3000 Layer gpt_neox.layers.1.mlp.dense_4h_to_h.weight: Rank = 512
# Step step3000 Layer gpt_neox.layers.1.mlp.dense_4h_to_h.bias: Rank = 1
# Step step3000 Layer gpt_neox.layers.2.input_layernorm.weight: Rank = 1
# Step step3000 Layer gpt_neox.layers.2.input_layernorm.bias: Rank = 1
# Step step3000 Layer gpt_neox.layers.2.post_attention_layernorm.weight: Rank = 1
# Step step3000 Layer gpt_neox.layers.2.post_attention_layernorm.bias: Rank = 1
# Step step3000 Layer gpt_neox.layers.2.attention.query_key_value.weight: Rank = 512
# Step step3000 Layer gpt_neox.layers.2.attention.query_key_value.bias: Rank = 1
# Step step3000 Layer gpt_neox.layers.2.attention.dense.weight: Rank = 512
# Step step3000 Layer gpt_neox.layers.2.attention.dense.bias: Rank = 1
# Step step3000 Layer gpt_neox.layers.2.mlp.dense_h_to_4h.weight: Rank = 512
# Step step3000 Layer gpt_neox.layers.2.mlp.dense_h_to_4h.bias: Rank = 1
# Step step3000 Layer gpt_neox.layers.2.mlp.dense_4h_to_h.weight: Rank = 512
# Step step3000 Layer gpt_neox.layers.2.mlp.dense_4h_to_h.bias: Rank = 1
# Step step3000 Layer gpt_neox.layers.3.input_layernorm.weight: Rank = 1
# Step step3000 Layer gpt_neox.layers.3.input_layernorm.bias: Rank = 1
# Step step3000 Layer gpt_neox.layers.3.post_attention_layernorm.weight: Rank = 1
# Step step3000 Layer gpt_neox.layers.3.post_attention_layernorm.bias: Rank = 1
# Step step3000 Layer gpt_neox.layers.3.attention.query_key_value.weight: Rank = 512
# Step step3000 Layer gpt_neox.layers.3.attention.query_key_value.bias: Rank = 1
# Step step3000 Layer gpt_neox.layers.3.attention.dense.weight: Rank = 512
# Step step3000 Layer gpt_neox.layers.3.attention.dense.bias: Rank = 1
# Step step3000 Layer gpt_neox.layers.3.mlp.dense_h_to_4h.weight: Rank = 512
# Step step3000 Layer gpt_neox.layers.3.mlp.dense_h_to_4h.bias: Rank = 1
# Step step3000 Layer gpt_neox.layers.3.mlp.dense_4h_to_h.weight: Rank = 512
# Step step3000 Layer gpt_neox.layers.3.mlp.dense_4h_to_h.bias: Rank = 1
# Step step3000 Layer gpt_neox.layers.4.input_layernorm.weight: Rank = 1
# Step step3000 Layer gpt_neox.layers.4.input_layernorm.bias: Rank = 1
# Step step3000 Layer gpt_neox.layers.4.post_attention_layernorm.weight: Rank = 1
# Step step3000 Layer gpt_neox.layers.4.post_attention_layernorm.bias: Rank = 1
# Step step3000 Layer gpt_neox.layers.4.attention.query_key_value.weight: Rank = 512
# Step step3000 Layer gpt_neox.layers.4.attention.query_key_value.bias: Rank = 1
# Step step3000 Layer gpt_neox.layers.4.attention.dense.weight: Rank = 512
# Step step3000 Layer gpt_neox.layers.4.attention.dense.bias: Rank = 1
# Step step3000 Layer gpt_neox.layers.4.mlp.dense_h_to_4h.weight: Rank = 512
# Step step3000 Layer gpt_neox.layers.4.mlp.dense_h_to_4h.bias: Rank = 1
# Step step3000 Layer gpt_neox.layers.4.mlp.dense_4h_to_h.weight: Rank = 512
# Step step3000 Layer gpt_neox.layers.4.mlp.dense_4h_to_h.bias: Rank = 1
# Step step3000 Layer gpt_neox.layers.5.input_layernorm.weight: Rank = 1
# Step step3000 Layer gpt_neox.layers.5.input_layernorm.bias: Rank = 1
# Step step3000 Layer gpt_neox.layers.5.post_attention_layernorm.weight: Rank = 1
# Step step3000 Layer gpt_neox.layers.5.post_attention_layernorm.bias: Rank = 1
# Step step3000 Layer gpt_neox.layers.5.attention.query_key_value.weight: Rank = 512
# Step step3000 Layer gpt_neox.layers.5.attention.query_key_value.bias: Rank = 1
# Step step3000 Layer gpt_neox.layers.5.attention.dense.weight: Rank = 512
# Step step3000 Layer gpt_neox.layers.5.attention.dense.bias: Rank = 1
# Step step3000 Layer gpt_neox.layers.5.mlp.dense_h_to_4h.weight: Rank = 512
# Step step3000 Layer gpt_neox.layers.5.mlp.dense_h_to_4h.bias: Rank = 1
# Step step3000 Layer gpt_neox.layers.5.mlp.dense_4h_to_h.weight: Rank = 512
# Step step3000 Layer gpt_neox.layers.5.mlp.dense_4h_to_h.bias: Rank = 1
# Step step3000 Layer gpt_neox.final_layer_norm.weight: Rank = 1
# Step step3000 Layer gpt_neox.final_layer_norm.bias: Rank = 1
#   2%|███▋                                                                                                                                                                          | 3/143 [00:12<10:02,  4.30s/it]
# Step step3000 Layer embed_out.weight: Rank = 512
# Step step4000 Layer gpt_neox.embed_in.weight: Rank = 512
# Step step4000 Layer gpt_neox.layers.0.input_layernorm.weight: Rank = 1
# Step step4000 Layer gpt_neox.layers.0.input_layernorm.bias: Rank = 1
# Step step4000 Layer gpt_neox.layers.0.post_attention_layernorm.weight: Rank = 1
# Step step4000 Layer gpt_neox.layers.0.post_attention_layernorm.bias: Rank = 1
# Step step4000 Layer gpt_neox.layers.0.attention.query_key_value.weight: Rank = 512
# Step step4000 Layer gpt_neox.layers.0.attention.query_key_value.bias: Rank = 1
# Step step4000 Layer gpt_neox.layers.0.attention.dense.weight: Rank = 512
# Step step4000 Layer gpt_neox.layers.0.attention.dense.bias: Rank = 1
# Step step4000 Layer gpt_neox.layers.0.mlp.dense_h_to_4h.weight: Rank = 512
# Step step4000 Layer gpt_neox.layers.0.mlp.dense_h_to_4h.bias: Rank = 1
# Step step4000 Layer gpt_neox.layers.0.mlp.dense_4h_to_h.weight: Rank = 512
# Step step4000 Layer gpt_neox.layers.0.mlp.dense_4h_to_h.bias: Rank = 1
# Step step4000 Layer gpt_neox.layers.1.input_layernorm.weight: Rank = 1
# Step step4000 Layer gpt_neox.layers.1.input_layernorm.bias: Rank = 1
# Step step4000 Layer gpt_neox.layers.1.post_attention_layernorm.weight: Rank = 1
# Step step4000 Layer gpt_neox.layers.1.post_attention_layernorm.bias: Rank = 1
# Step step4000 Layer gpt_neox.layers.1.attention.query_key_value.weight: Rank = 512
# Step step4000 Layer gpt_neox.layers.1.attention.query_key_value.bias: Rank = 1
# Step step4000 Layer gpt_neox.layers.1.attention.dense.weight: Rank = 512
# Step step4000 Layer gpt_neox.layers.1.attention.dense.bias: Rank = 1
# Step step4000 Layer gpt_neox.layers.1.mlp.dense_h_to_4h.weight: Rank = 512
# Step step4000 Layer gpt_neox.layers.1.mlp.dense_h_to_4h.bias: Rank = 1
# Step step4000 Layer gpt_neox.layers.1.mlp.dense_4h_to_h.weight: Rank = 512
# Step step4000 Layer gpt_neox.layers.1.mlp.dense_4h_to_h.bias: Rank = 1
# Step step4000 Layer gpt_neox.layers.2.input_layernorm.weight: Rank = 1
# Step step4000 Layer gpt_neox.layers.2.input_layernorm.bias: Rank = 1
# Step step4000 Layer gpt_neox.layers.2.post_attention_layernorm.weight: Rank = 1
# Step step4000 Layer gpt_neox.layers.2.post_attention_layernorm.bias: Rank = 1
# Step step4000 Layer gpt_neox.layers.2.attention.query_key_value.weight: Rank = 512
# Step step4000 Layer gpt_neox.layers.2.attention.query_key_value.bias: Rank = 1
# Step step4000 Layer gpt_neox.layers.2.attention.dense.weight: Rank = 512
# Step step4000 Layer gpt_neox.layers.2.attention.dense.bias: Rank = 1
# Step step4000 Layer gpt_neox.layers.2.mlp.dense_h_to_4h.weight: Rank = 512
# Step step4000 Layer gpt_neox.layers.2.mlp.dense_h_to_4h.bias: Rank = 1
# Step step4000 Layer gpt_neox.layers.2.mlp.dense_4h_to_h.weight: Rank = 512
# Step step4000 Layer gpt_neox.layers.2.mlp.dense_4h_to_h.bias: Rank = 1
# Step step4000 Layer gpt_neox.layers.3.input_layernorm.weight: Rank = 1
# Step step4000 Layer gpt_neox.layers.3.input_layernorm.bias: Rank = 1
# Step step4000 Layer gpt_neox.layers.3.post_attention_layernorm.weight: Rank = 1
# Step step4000 Layer gpt_neox.layers.3.post_attention_layernorm.bias: Rank = 1
# Step step4000 Layer gpt_neox.layers.3.attention.query_key_value.weight: Rank = 512
# Step step4000 Layer gpt_neox.layers.3.attention.query_key_value.bias: Rank = 1
# Step step4000 Layer gpt_neox.layers.3.attention.dense.weight: Rank = 512
# Step step4000 Layer gpt_neox.layers.3.attention.dense.bias: Rank = 1
# Step step4000 Layer gpt_neox.layers.3.mlp.dense_h_to_4h.weight: Rank = 512
# Step step4000 Layer gpt_neox.layers.3.mlp.dense_h_to_4h.bias: Rank = 1
# Step step4000 Layer gpt_neox.layers.3.mlp.dense_4h_to_h.weight: Rank = 512
# Step step4000 Layer gpt_neox.layers.3.mlp.dense_4h_to_h.bias: Rank = 1
# Step step4000 Layer gpt_neox.layers.4.input_layernorm.weight: Rank = 1
# Step step4000 Layer gpt_neox.layers.4.input_layernorm.bias: Rank = 1
# Step step4000 Layer gpt_neox.layers.4.post_attention_layernorm.weight: Rank = 1
# Step step4000 Layer gpt_neox.layers.4.post_attention_layernorm.bias: Rank = 1
# Step step4000 Layer gpt_neox.layers.4.attention.query_key_value.weight: Rank = 512
# Step step4000 Layer gpt_neox.layers.4.attention.query_key_value.bias: Rank = 1
# Step step4000 Layer gpt_neox.layers.4.attention.dense.weight: Rank = 512
# Step step4000 Layer gpt_neox.layers.4.attention.dense.bias: Rank = 1
# Step step4000 Layer gpt_neox.layers.4.mlp.dense_h_to_4h.weight: Rank = 512
# Step step4000 Layer gpt_neox.layers.4.mlp.dense_h_to_4h.bias: Rank = 1
# Step step4000 Layer gpt_neox.layers.4.mlp.dense_4h_to_h.weight: Rank = 512
# Step step4000 Layer gpt_neox.layers.4.mlp.dense_4h_to_h.bias: Rank = 1
# Step step4000 Layer gpt_neox.layers.5.input_layernorm.weight: Rank = 1
# Step step4000 Layer gpt_neox.layers.5.input_layernorm.bias: Rank = 1
# Step step4000 Layer gpt_neox.layers.5.post_attention_layernorm.weight: Rank = 1
# Step step4000 Layer gpt_neox.layers.5.post_attention_layernorm.bias: Rank = 1
# Step step4000 Layer gpt_neox.layers.5.attention.query_key_value.weight: Rank = 512
# Step step4000 Layer gpt_neox.layers.5.attention.query_key_value.bias: Rank = 1
# Step step4000 Layer gpt_neox.layers.5.attention.dense.weight: Rank = 512
# Step step4000 Layer gpt_neox.layers.5.attention.dense.bias: Rank = 1
# Step step4000 Layer gpt_neox.layers.5.mlp.dense_h_to_4h.weight: Rank = 512
# Step step4000 Layer gpt_neox.layers.5.mlp.dense_h_to_4h.bias: Rank = 1
# Step step4000 Layer gpt_neox.layers.5.mlp.dense_4h_to_h.weight: Rank = 512
# Step step4000 Layer gpt_neox.layers.5.mlp.dense_4h_to_h.bias: Rank = 1
# Step step4000 Layer gpt_neox.final_layer_norm.weight: Rank = 1
# Step step4000 Layer gpt_neox.final_layer_norm.bias: Rank = 1
#   3%|████▊                                                                                                                                                                         | 4/143 [00:17<10:03,  4.34s/it]
# Step step4000 Layer embed_out.weight: Rank = 512
# Step step5000 Layer gpt_neox.embed_in.weight: Rank = 512
# Step step5000 Layer gpt_neox.layers.0.input_layernorm.weight: Rank = 1
# Step step5000 Layer gpt_neox.layers.0.input_layernorm.bias: Rank = 1
# Step step5000 Layer gpt_neox.layers.0.post_attention_layernorm.weight: Rank = 1
# Step step5000 Layer gpt_neox.layers.0.post_attention_layernorm.bias: Rank = 1
# Step step5000 Layer gpt_neox.layers.0.attention.query_key_value.weight: Rank = 512
# Step step5000 Layer gpt_neox.layers.0.attention.query_key_value.bias: Rank = 1
# Step step5000 Layer gpt_neox.layers.0.attention.dense.weight: Rank = 512
# Step step5000 Layer gpt_neox.layers.0.attention.dense.bias: Rank = 1
# Step step5000 Layer gpt_neox.layers.0.mlp.dense_h_to_4h.weight: Rank = 512
# Step step5000 Layer gpt_neox.layers.0.mlp.dense_h_to_4h.bias: Rank = 1
# Step step5000 Layer gpt_neox.layers.0.mlp.dense_4h_to_h.weight: Rank = 512
# Step step5000 Layer gpt_neox.layers.0.mlp.dense_4h_to_h.bias: Rank = 1
# Step step5000 Layer gpt_neox.layers.1.input_layernorm.weight: Rank = 1
# Step step5000 Layer gpt_neox.layers.1.input_layernorm.bias: Rank = 1
# Step step5000 Layer gpt_neox.layers.1.post_attention_layernorm.weight: Rank = 1
# Step step5000 Layer gpt_neox.layers.1.post_attention_layernorm.bias: Rank = 1
# Step step5000 Layer gpt_neox.layers.1.attention.query_key_value.weight: Rank = 512
# Step step5000 Layer gpt_neox.layers.1.attention.query_key_value.bias: Rank = 1
# Step step5000 Layer gpt_neox.layers.1.attention.dense.weight: Rank = 512
# Step step5000 Layer gpt_neox.layers.1.attention.dense.bias: Rank = 1
# Step step5000 Layer gpt_neox.layers.1.mlp.dense_h_to_4h.weight: Rank = 512
# Step step5000 Layer gpt_neox.layers.1.mlp.dense_h_to_4h.bias: Rank = 1
# Step step5000 Layer gpt_neox.layers.1.mlp.dense_4h_to_h.weight: Rank = 512
# Step step5000 Layer gpt_neox.layers.1.mlp.dense_4h_to_h.bias: Rank = 1
# Step step5000 Layer gpt_neox.layers.2.input_layernorm.weight: Rank = 1
# Step step5000 Layer gpt_neox.layers.2.input_layernorm.bias: Rank = 1
# Step step5000 Layer gpt_neox.layers.2.post_attention_layernorm.weight: Rank = 1
# Step step5000 Layer gpt_neox.layers.2.post_attention_layernorm.bias: Rank = 1
# Step step5000 Layer gpt_neox.layers.2.attention.query_key_value.weight: Rank = 512
# Step step5000 Layer gpt_neox.layers.2.attention.query_key_value.bias: Rank = 1
# Step step5000 Layer gpt_neox.layers.2.attention.dense.weight: Rank = 512
# Step step5000 Layer gpt_neox.layers.2.attention.dense.bias: Rank = 1
# Step step5000 Layer gpt_neox.layers.2.mlp.dense_h_to_4h.weight: Rank = 512
# Step step5000 Layer gpt_neox.layers.2.mlp.dense_h_to_4h.bias: Rank = 1
# Step step5000 Layer gpt_neox.layers.2.mlp.dense_4h_to_h.weight: Rank = 512
# Step step5000 Layer gpt_neox.layers.2.mlp.dense_4h_to_h.bias: Rank = 1
# Step step5000 Layer gpt_neox.layers.3.input_layernorm.weight: Rank = 1
# Step step5000 Layer gpt_neox.layers.3.input_layernorm.bias: Rank = 1
# Step step5000 Layer gpt_neox.layers.3.post_attention_layernorm.weight: Rank = 1
# Step step5000 Layer gpt_neox.layers.3.post_attention_layernorm.bias: Rank = 1
# Step step5000 Layer gpt_neox.layers.3.attention.query_key_value.weight: Rank = 512
# Step step5000 Layer gpt_neox.layers.3.attention.query_key_value.bias: Rank = 1
# Step step5000 Layer gpt_neox.layers.3.attention.dense.weight: Rank = 512
# Step step5000 Layer gpt_neox.layers.3.attention.dense.bias: Rank = 1
# Step step5000 Layer gpt_neox.layers.3.mlp.dense_h_to_4h.weight: Rank = 512
# Step step5000 Layer gpt_neox.layers.3.mlp.dense_h_to_4h.bias: Rank = 1
# Step step5000 Layer gpt_neox.layers.3.mlp.dense_4h_to_h.weight: Rank = 512
# Step step5000 Layer gpt_neox.layers.3.mlp.dense_4h_to_h.bias: Rank = 1
# Step step5000 Layer gpt_neox.layers.4.input_layernorm.weight: Rank = 1
# Step step5000 Layer gpt_neox.layers.4.input_layernorm.bias: Rank = 1
# Step step5000 Layer gpt_neox.layers.4.post_attention_layernorm.weight: Rank = 1
# Step step5000 Layer gpt_neox.layers.4.post_attention_layernorm.bias: Rank = 1
# Step step5000 Layer gpt_neox.layers.4.attention.query_key_value.weight: Rank = 512
# Step step5000 Layer gpt_neox.layers.4.attention.query_key_value.bias: Rank = 1
# Step step5000 Layer gpt_neox.layers.4.attention.dense.weight: Rank = 512
# Step step5000 Layer gpt_neox.layers.4.attention.dense.bias: Rank = 1
# Step step5000 Layer gpt_neox.layers.4.mlp.dense_h_to_4h.weight: Rank = 512
# Step step5000 Layer gpt_neox.layers.4.mlp.dense_h_to_4h.bias: Rank = 1
# Step step5000 Layer gpt_neox.layers.4.mlp.dense_4h_to_h.weight: Rank = 512
# Step step5000 Layer gpt_neox.layers.4.mlp.dense_4h_to_h.bias: Rank = 1
# Step step5000 Layer gpt_neox.layers.5.input_layernorm.weight: Rank = 1
# Step step5000 Layer gpt_neox.layers.5.input_layernorm.bias: Rank = 1
# Step step5000 Layer gpt_neox.layers.5.post_attention_layernorm.weight: Rank = 1
# Step step5000 Layer gpt_neox.layers.5.post_attention_layernorm.bias: Rank = 1
# Step step5000 Layer gpt_neox.layers.5.attention.query_key_value.weight: Rank = 512
# Step step5000 Layer gpt_neox.layers.5.attention.query_key_value.bias: Rank = 1
# Step step5000 Layer gpt_neox.layers.5.attention.dense.weight: Rank = 512
# Step step5000 Layer gpt_neox.layers.5.attention.dense.bias: Rank = 1
# Step step5000 Layer gpt_neox.layers.5.mlp.dense_h_to_4h.weight: Rank = 512
# Step step5000 Layer gpt_neox.layers.5.mlp.dense_h_to_4h.bias: Rank = 1
# Step step5000 Layer gpt_neox.layers.5.mlp.dense_4h_to_h.weight: Rank = 512
# Step step5000 Layer gpt_neox.layers.5.mlp.dense_4h_to_h.bias: Rank = 1
# Step step5000 Layer gpt_neox.final_layer_norm.weight: Rank = 1
# Step step5000 Layer gpt_neox.final_layer_norm.bias: Rank = 1
#   3%|██████                                                                                                                                                                        | 5/143 [00:21<10:00,  4.35s/it]
# Step step5000 Layer embed_out.weight: Rank = 512
# Step step6000 Layer gpt_neox.embed_in.weight: Rank = 512
# Step step6000 Layer gpt_neox.layers.0.input_layernorm.weight: Rank = 1
# Step step6000 Layer gpt_neox.layers.0.input_layernorm.bias: Rank = 1
# Step step6000 Layer gpt_neox.layers.0.post_attention_layernorm.weight: Rank = 1
# Step step6000 Layer gpt_neox.layers.0.post_attention_layernorm.bias: Rank = 1
# Step step6000 Layer gpt_neox.layers.0.attention.query_key_value.weight: Rank = 512
# Step step6000 Layer gpt_neox.layers.0.attention.query_key_value.bias: Rank = 1
# Step step6000 Layer gpt_neox.layers.0.attention.dense.weight: Rank = 512
# Step step6000 Layer gpt_neox.layers.0.attention.dense.bias: Rank = 1
# Step step6000 Layer gpt_neox.layers.0.mlp.dense_h_to_4h.weight: Rank = 512
# Step step6000 Layer gpt_neox.layers.0.mlp.dense_h_to_4h.bias: Rank = 1
# Step step6000 Layer gpt_neox.layers.0.mlp.dense_4h_to_h.weight: Rank = 512
# Step step6000 Layer gpt_neox.layers.0.mlp.dense_4h_to_h.bias: Rank = 1
# Step step6000 Layer gpt_neox.layers.1.input_layernorm.weight: Rank = 1
# Step step6000 Layer gpt_neox.layers.1.input_layernorm.bias: Rank = 1
# Step step6000 Layer gpt_neox.layers.1.post_attention_layernorm.weight: Rank = 1
# Step step6000 Layer gpt_neox.layers.1.post_attention_layernorm.bias: Rank = 1
# Step step6000 Layer gpt_neox.layers.1.attention.query_key_value.weight: Rank = 512
# Step step6000 Layer gpt_neox.layers.1.attention.query_key_value.bias: Rank = 1
# Step step6000 Layer gpt_neox.layers.1.attention.dense.weight: Rank = 512
# Step step6000 Layer gpt_neox.layers.1.attention.dense.bias: Rank = 1
# Step step6000 Layer gpt_neox.layers.1.mlp.dense_h_to_4h.weight: Rank = 512
# Step step6000 Layer gpt_neox.layers.1.mlp.dense_h_to_4h.bias: Rank = 1
# Step step6000 Layer gpt_neox.layers.1.mlp.dense_4h_to_h.weight: Rank = 512
# Step step6000 Layer gpt_neox.layers.1.mlp.dense_4h_to_h.bias: Rank = 1
# Step step6000 Layer gpt_neox.layers.2.input_layernorm.weight: Rank = 1
# Step step6000 Layer gpt_neox.layers.2.input_layernorm.bias: Rank = 1
# Step step6000 Layer gpt_neox.layers.2.post_attention_layernorm.weight: Rank = 1
# Step step6000 Layer gpt_neox.layers.2.post_attention_layernorm.bias: Rank = 1
# Step step6000 Layer gpt_neox.layers.2.attention.query_key_value.weight: Rank = 512
# Step step6000 Layer gpt_neox.layers.2.attention.query_key_value.bias: Rank = 1
# Step step6000 Layer gpt_neox.layers.2.attention.dense.weight: Rank = 512
# Step step6000 Layer gpt_neox.layers.2.attention.dense.bias: Rank = 1
# Step step6000 Layer gpt_neox.layers.2.mlp.dense_h_to_4h.weight: Rank = 512
# Step step6000 Layer gpt_neox.layers.2.mlp.dense_h_to_4h.bias: Rank = 1
# Step step6000 Layer gpt_neox.layers.2.mlp.dense_4h_to_h.weight: Rank = 512
# Step step6000 Layer gpt_neox.layers.2.mlp.dense_4h_to_h.bias: Rank = 1
# Step step6000 Layer gpt_neox.layers.3.input_layernorm.weight: Rank = 1
# Step step6000 Layer gpt_neox.layers.3.input_layernorm.bias: Rank = 1
# Step step6000 Layer gpt_neox.layers.3.post_attention_layernorm.weight: Rank = 1
# Step step6000 Layer gpt_neox.layers.3.post_attention_layernorm.bias: Rank = 1
# Step step6000 Layer gpt_neox.layers.3.attention.query_key_value.weight: Rank = 512
# Step step6000 Layer gpt_neox.layers.3.attention.query_key_value.bias: Rank = 1
# Step step6000 Layer gpt_neox.layers.3.attention.dense.weight: Rank = 512
# Step step6000 Layer gpt_neox.layers.3.attention.dense.bias: Rank = 1
# Step step6000 Layer gpt_neox.layers.3.mlp.dense_h_to_4h.weight: Rank = 512
# Step step6000 Layer gpt_neox.layers.3.mlp.dense_h_to_4h.bias: Rank = 1
# Step step6000 Layer gpt_neox.layers.3.mlp.dense_4h_to_h.weight: Rank = 512
# Step step6000 Layer gpt_neox.layers.3.mlp.dense_4h_to_h.bias: Rank = 1
# Step step6000 Layer gpt_neox.layers.4.input_layernorm.weight: Rank = 1
# Step step6000 Layer gpt_neox.layers.4.input_layernorm.bias: Rank = 1
# Step step6000 Layer gpt_neox.layers.4.post_attention_layernorm.weight: Rank = 1
# Step step6000 Layer gpt_neox.layers.4.post_attention_layernorm.bias: Rank = 1
# Step step6000 Layer gpt_neox.layers.4.attention.query_key_value.weight: Rank = 512
# Step step6000 Layer gpt_neox.layers.4.attention.query_key_value.bias: Rank = 1
# Step step6000 Layer gpt_neox.layers.4.attention.dense.weight: Rank = 512
# Step step6000 Layer gpt_neox.layers.4.attention.dense.bias: Rank = 1
# Step step6000 Layer gpt_neox.layers.4.mlp.dense_h_to_4h.weight: Rank = 512
# Step step6000 Layer gpt_neox.layers.4.mlp.dense_h_to_4h.bias: Rank = 1
# Step step6000 Layer gpt_neox.layers.4.mlp.dense_4h_to_h.weight: Rank = 512
# Step step6000 Layer gpt_neox.layers.4.mlp.dense_4h_to_h.bias: Rank = 1
# Step step6000 Layer gpt_neox.layers.5.input_layernorm.weight: Rank = 1
# Step step6000 Layer gpt_neox.layers.5.input_layernorm.bias: Rank = 1
# Step step6000 Layer gpt_neox.layers.5.post_attention_layernorm.weight: Rank = 1
# Step step6000 Layer gpt_neox.layers.5.post_attention_layernorm.bias: Rank = 1
# Step step6000 Layer gpt_neox.layers.5.attention.query_key_value.weight: Rank = 512
# Step step6000 Layer gpt_neox.layers.5.attention.query_key_value.bias: Rank = 1
# Step step6000 Layer gpt_neox.layers.5.attention.dense.weight: Rank = 512
# Step step6000 Layer gpt_neox.layers.5.attention.dense.bias: Rank = 1
# Step step6000 Layer gpt_neox.layers.5.mlp.dense_h_to_4h.weight: Rank = 512
# Step step6000 Layer gpt_neox.layers.5.mlp.dense_h_to_4h.bias: Rank = 1
# Step step6000 Layer gpt_neox.layers.5.mlp.dense_4h_to_h.weight: Rank = 512
# Step step6000 Layer gpt_neox.layers.5.mlp.dense_4h_to_h.bias: Rank = 1
# Step step6000 Layer gpt_neox.final_layer_norm.weight: Rank = 1
# Step step6000 Layer gpt_neox.final_layer_norm.bias: Rank = 1
#   4%|███████▎                                                                                                                                                                      | 6/143 [00:25<09:55,  4.35s/it]
# Step step6000 Layer embed_out.weight: Rank = 512
# Step step7000 Layer gpt_neox.embed_in.weight: Rank = 512
# Step step7000 Layer gpt_neox.layers.0.input_layernorm.weight: Rank = 1
# Step step7000 Layer gpt_neox.layers.0.input_layernorm.bias: Rank = 1
# Step step7000 Layer gpt_neox.layers.0.post_attention_layernorm.weight: Rank = 1
# Step step7000 Layer gpt_neox.layers.0.post_attention_layernorm.bias: Rank = 1
# Step step7000 Layer gpt_neox.layers.0.attention.query_key_value.weight: Rank = 512
# Step step7000 Layer gpt_neox.layers.0.attention.query_key_value.bias: Rank = 1
# Step step7000 Layer gpt_neox.layers.0.attention.dense.weight: Rank = 512
# Step step7000 Layer gpt_neox.layers.0.attention.dense.bias: Rank = 1
# Step step7000 Layer gpt_neox.layers.0.mlp.dense_h_to_4h.weight: Rank = 512
# Step step7000 Layer gpt_neox.layers.0.mlp.dense_h_to_4h.bias: Rank = 1
# Step step7000 Layer gpt_neox.layers.0.mlp.dense_4h_to_h.weight: Rank = 512
# Step step7000 Layer gpt_neox.layers.0.mlp.dense_4h_to_h.bias: Rank = 1
# Step step7000 Layer gpt_neox.layers.1.input_layernorm.weight: Rank = 1
# Step step7000 Layer gpt_neox.layers.1.input_layernorm.bias: Rank = 1
# Step step7000 Layer gpt_neox.layers.1.post_attention_layernorm.weight: Rank = 1
# Step step7000 Layer gpt_neox.layers.1.post_attention_layernorm.bias: Rank = 1
# Step step7000 Layer gpt_neox.layers.1.attention.query_key_value.weight: Rank = 512
# Step step7000 Layer gpt_neox.layers.1.attention.query_key_value.bias: Rank = 1
# Step step7000 Layer gpt_neox.layers.1.attention.dense.weight: Rank = 512
# Step step7000 Layer gpt_neox.layers.1.attention.dense.bias: Rank = 1
# Step step7000 Layer gpt_neox.layers.1.mlp.dense_h_to_4h.weight: Rank = 512
# Step step7000 Layer gpt_neox.layers.1.mlp.dense_h_to_4h.bias: Rank = 1
# Step step7000 Layer gpt_neox.layers.1.mlp.dense_4h_to_h.weight: Rank = 512
# Step step7000 Layer gpt_neox.layers.1.mlp.dense_4h_to_h.bias: Rank = 1
# Step step7000 Layer gpt_neox.layers.2.input_layernorm.weight: Rank = 1
# Step step7000 Layer gpt_neox.layers.2.input_layernorm.bias: Rank = 1
# Step step7000 Layer gpt_neox.layers.2.post_attention_layernorm.weight: Rank = 1
# Step step7000 Layer gpt_neox.layers.2.post_attention_layernorm.bias: Rank = 1
# Step step7000 Layer gpt_neox.layers.2.attention.query_key_value.weight: Rank = 512
# Step step7000 Layer gpt_neox.layers.2.attention.query_key_value.bias: Rank = 1
# Step step7000 Layer gpt_neox.layers.2.attention.dense.weight: Rank = 512
# Step step7000 Layer gpt_neox.layers.2.attention.dense.bias: Rank = 1
# Step step7000 Layer gpt_neox.layers.2.mlp.dense_h_to_4h.weight: Rank = 512
# Step step7000 Layer gpt_neox.layers.2.mlp.dense_h_to_4h.bias: Rank = 1
# Step step7000 Layer gpt_neox.layers.2.mlp.dense_4h_to_h.weight: Rank = 512
# Step step7000 Layer gpt_neox.layers.2.mlp.dense_4h_to_h.bias: Rank = 1
# Step step7000 Layer gpt_neox.layers.3.input_layernorm.weight: Rank = 1
# Step step7000 Layer gpt_neox.layers.3.input_layernorm.bias: Rank = 1
# Step step7000 Layer gpt_neox.layers.3.post_attention_layernorm.weight: Rank = 1
# Step step7000 Layer gpt_neox.layers.3.post_attention_layernorm.bias: Rank = 1
# Step step7000 Layer gpt_neox.layers.3.attention.query_key_value.weight: Rank = 512
# Step step7000 Layer gpt_neox.layers.3.attention.query_key_value.bias: Rank = 1
# Step step7000 Layer gpt_neox.layers.3.attention.dense.weight: Rank = 512
# Step step7000 Layer gpt_neox.layers.3.attention.dense.bias: Rank = 1
# Step step7000 Layer gpt_neox.layers.3.mlp.dense_h_to_4h.weight: Rank = 512
# Step step7000 Layer gpt_neox.layers.3.mlp.dense_h_to_4h.bias: Rank = 1
# Step step7000 Layer gpt_neox.layers.3.mlp.dense_4h_to_h.weight: Rank = 512
# Step step7000 Layer gpt_neox.layers.3.mlp.dense_4h_to_h.bias: Rank = 1
# Step step7000 Layer gpt_neox.layers.4.input_layernorm.weight: Rank = 1
# Step step7000 Layer gpt_neox.layers.4.input_layernorm.bias: Rank = 1
# Step step7000 Layer gpt_neox.layers.4.post_attention_layernorm.weight: Rank = 1
# Step step7000 Layer gpt_neox.layers.4.post_attention_layernorm.bias: Rank = 1
# Step step7000 Layer gpt_neox.layers.4.attention.query_key_value.weight: Rank = 512
# Step step7000 Layer gpt_neox.layers.4.attention.query_key_value.bias: Rank = 1
# Step step7000 Layer gpt_neox.layers.4.attention.dense.weight: Rank = 512
# Step step7000 Layer gpt_neox.layers.4.attention.dense.bias: Rank = 1
# Step step7000 Layer gpt_neox.layers.4.mlp.dense_h_to_4h.weight: Rank = 512
# Step step7000 Layer gpt_neox.layers.4.mlp.dense_h_to_4h.bias: Rank = 1
# Step step7000 Layer gpt_neox.layers.4.mlp.dense_4h_to_h.weight: Rank = 512
# Step step7000 Layer gpt_neox.layers.4.mlp.dense_4h_to_h.bias: Rank = 1
# Step step7000 Layer gpt_neox.layers.5.input_layernorm.weight: Rank = 1
# Step step7000 Layer gpt_neox.layers.5.input_layernorm.bias: Rank = 1
# Step step7000 Layer gpt_neox.layers.5.post_attention_layernorm.weight: Rank = 1
# Step step7000 Layer gpt_neox.layers.5.post_attention_layernorm.bias: Rank = 1
# Step step7000 Layer gpt_neox.layers.5.attention.query_key_value.weight: Rank = 512
# Step step7000 Layer gpt_neox.layers.5.attention.query_key_value.bias: Rank = 1
# Step step7000 Layer gpt_neox.layers.5.attention.dense.weight: Rank = 511
# Step step7000 Layer gpt_neox.layers.5.attention.dense.bias: Rank = 1
# Step step7000 Layer gpt_neox.layers.5.mlp.dense_h_to_4h.weight: Rank = 512
# Step step7000 Layer gpt_neox.layers.5.mlp.dense_h_to_4h.bias: Rank = 1
# Step step7000 Layer gpt_neox.layers.5.mlp.dense_4h_to_h.weight: Rank = 512
# Step step7000 Layer gpt_neox.layers.5.mlp.dense_4h_to_h.bias: Rank = 1
# Step step7000 Layer gpt_neox.final_layer_norm.weight: Rank = 1
# Step step7000 Layer gpt_neox.final_layer_norm.bias: Rank = 1
#   5%|████████▌                                                                                                                                                                     | 7/143 [00:30<10:00,  4.41s/it]
# Step step7000 Layer embed_out.weight: Rank = 512
# Step step8000 Layer gpt_neox.embed_in.weight: Rank = 512
# Step step8000 Layer gpt_neox.layers.0.input_layernorm.weight: Rank = 1
# Step step8000 Layer gpt_neox.layers.0.input_layernorm.bias: Rank = 1
# Step step8000 Layer gpt_neox.layers.0.post_attention_layernorm.weight: Rank = 1
# Step step8000 Layer gpt_neox.layers.0.post_attention_layernorm.bias: Rank = 1
# Step step8000 Layer gpt_neox.layers.0.attention.query_key_value.weight: Rank = 512
# Step step8000 Layer gpt_neox.layers.0.attention.query_key_value.bias: Rank = 1
# Step step8000 Layer gpt_neox.layers.0.attention.dense.weight: Rank = 512
# Step step8000 Layer gpt_neox.layers.0.attention.dense.bias: Rank = 1
# Step step8000 Layer gpt_neox.layers.0.mlp.dense_h_to_4h.weight: Rank = 512
# Step step8000 Layer gpt_neox.layers.0.mlp.dense_h_to_4h.bias: Rank = 1
# Step step8000 Layer gpt_neox.layers.0.mlp.dense_4h_to_h.weight: Rank = 512
# Step step8000 Layer gpt_neox.layers.0.mlp.dense_4h_to_h.bias: Rank = 1
# Step step8000 Layer gpt_neox.layers.1.input_layernorm.weight: Rank = 1
# Step step8000 Layer gpt_neox.layers.1.input_layernorm.bias: Rank = 1
# Step step8000 Layer gpt_neox.layers.1.post_attention_layernorm.weight: Rank = 1
# Step step8000 Layer gpt_neox.layers.1.post_attention_layernorm.bias: Rank = 1
# Step step8000 Layer gpt_neox.layers.1.attention.query_key_value.weight: Rank = 512
# Step step8000 Layer gpt_neox.layers.1.attention.query_key_value.bias: Rank = 1
# Step step8000 Layer gpt_neox.layers.1.attention.dense.weight: Rank = 512
# Step step8000 Layer gpt_neox.layers.1.attention.dense.bias: Rank = 1
# Step step8000 Layer gpt_neox.layers.1.mlp.dense_h_to_4h.weight: Rank = 512
# Step step8000 Layer gpt_neox.layers.1.mlp.dense_h_to_4h.bias: Rank = 1
# Step step8000 Layer gpt_neox.layers.1.mlp.dense_4h_to_h.weight: Rank = 512
# Step step8000 Layer gpt_neox.layers.1.mlp.dense_4h_to_h.bias: Rank = 1
# Step step8000 Layer gpt_neox.layers.2.input_layernorm.weight: Rank = 1
# Step step8000 Layer gpt_neox.layers.2.input_layernorm.bias: Rank = 1
# Step step8000 Layer gpt_neox.layers.2.post_attention_layernorm.weight: Rank = 1
# Step step8000 Layer gpt_neox.layers.2.post_attention_layernorm.bias: Rank = 1
# Step step8000 Layer gpt_neox.layers.2.attention.query_key_value.weight: Rank = 512
# Step step8000 Layer gpt_neox.layers.2.attention.query_key_value.bias: Rank = 1
# Step step8000 Layer gpt_neox.layers.2.attention.dense.weight: Rank = 512
# Step step8000 Layer gpt_neox.layers.2.attention.dense.bias: Rank = 1
# Step step8000 Layer gpt_neox.layers.2.mlp.dense_h_to_4h.weight: Rank = 512
# Step step8000 Layer gpt_neox.layers.2.mlp.dense_h_to_4h.bias: Rank = 1
# Step step8000 Layer gpt_neox.layers.2.mlp.dense_4h_to_h.weight: Rank = 512
# Step step8000 Layer gpt_neox.layers.2.mlp.dense_4h_to_h.bias: Rank = 1
# Step step8000 Layer gpt_neox.layers.3.input_layernorm.weight: Rank = 1
# Step step8000 Layer gpt_neox.layers.3.input_layernorm.bias: Rank = 1
# Step step8000 Layer gpt_neox.layers.3.post_attention_layernorm.weight: Rank = 1
# Step step8000 Layer gpt_neox.layers.3.post_attention_layernorm.bias: Rank = 1
# Step step8000 Layer gpt_neox.layers.3.attention.query_key_value.weight: Rank = 512
# Step step8000 Layer gpt_neox.layers.3.attention.query_key_value.bias: Rank = 1
# Step step8000 Layer gpt_neox.layers.3.attention.dense.weight: Rank = 512
# Step step8000 Layer gpt_neox.layers.3.attention.dense.bias: Rank = 1
# Step step8000 Layer gpt_neox.layers.3.mlp.dense_h_to_4h.weight: Rank = 512
# Step step8000 Layer gpt_neox.layers.3.mlp.dense_h_to_4h.bias: Rank = 1
# Step step8000 Layer gpt_neox.layers.3.mlp.dense_4h_to_h.weight: Rank = 512
# Step step8000 Layer gpt_neox.layers.3.mlp.dense_4h_to_h.bias: Rank = 1
# Step step8000 Layer gpt_neox.layers.4.input_layernorm.weight: Rank = 1
# Step step8000 Layer gpt_neox.layers.4.input_layernorm.bias: Rank = 1
# Step step8000 Layer gpt_neox.layers.4.post_attention_layernorm.weight: Rank = 1
# Step step8000 Layer gpt_neox.layers.4.post_attention_layernorm.bias: Rank = 1
# Step step8000 Layer gpt_neox.layers.4.attention.query_key_value.weight: Rank = 512
# Step step8000 Layer gpt_neox.layers.4.attention.query_key_value.bias: Rank = 1
# Step step8000 Layer gpt_neox.layers.4.attention.dense.weight: Rank = 512
# Step step8000 Layer gpt_neox.layers.4.attention.dense.bias: Rank = 1
# Step step8000 Layer gpt_neox.layers.4.mlp.dense_h_to_4h.weight: Rank = 512
# Step step8000 Layer gpt_neox.layers.4.mlp.dense_h_to_4h.bias: Rank = 1
# Step step8000 Layer gpt_neox.layers.4.mlp.dense_4h_to_h.weight: Rank = 512
# Step step8000 Layer gpt_neox.layers.4.mlp.dense_4h_to_h.bias: Rank = 1
# Step step8000 Layer gpt_neox.layers.5.input_layernorm.weight: Rank = 1
# Step step8000 Layer gpt_neox.layers.5.input_layernorm.bias: Rank = 1
# Step step8000 Layer gpt_neox.layers.5.post_attention_layernorm.weight: Rank = 1
# Step step8000 Layer gpt_neox.layers.5.post_attention_layernorm.bias: Rank = 1
# Step step8000 Layer gpt_neox.layers.5.attention.query_key_value.weight: Rank = 512
# Step step8000 Layer gpt_neox.layers.5.attention.query_key_value.bias: Rank = 1
# Step step8000 Layer gpt_neox.layers.5.attention.dense.weight: Rank = 512
# Step step8000 Layer gpt_neox.layers.5.attention.dense.bias: Rank = 1
# Step step8000 Layer gpt_neox.layers.5.mlp.dense_h_to_4h.weight: Rank = 512
# Step step8000 Layer gpt_neox.layers.5.mlp.dense_h_to_4h.bias: Rank = 1
# Step step8000 Layer gpt_neox.layers.5.mlp.dense_4h_to_h.weight: Rank = 512
# Step step8000 Layer gpt_neox.layers.5.mlp.dense_4h_to_h.bias: Rank = 1
# Step step8000 Layer gpt_neox.final_layer_norm.weight: Rank = 1
# Step step8000 Layer gpt_neox.final_layer_norm.bias: Rank = 1
#   6%|█████████▋                                                                                                                                                                    | 8/143 [00:35<10:18,  4.58s/it]
# Step step8000 Layer embed_out.weight: Rank = 512
# Step step9000 Layer gpt_neox.embed_in.weight: Rank = 512
# Step step9000 Layer gpt_neox.layers.0.input_layernorm.weight: Rank = 1
# Step step9000 Layer gpt_neox.layers.0.input_layernorm.bias: Rank = 1
# Step step9000 Layer gpt_neox.layers.0.post_attention_layernorm.weight: Rank = 1
# Step step9000 Layer gpt_neox.layers.0.post_attention_layernorm.bias: Rank = 1
# Step step9000 Layer gpt_neox.layers.0.attention.query_key_value.weight: Rank = 512
# Step step9000 Layer gpt_neox.layers.0.attention.query_key_value.bias: Rank = 1
# Step step9000 Layer gpt_neox.layers.0.attention.dense.weight: Rank = 512
# Step step9000 Layer gpt_neox.layers.0.attention.dense.bias: Rank = 1
# Step step9000 Layer gpt_neox.layers.0.mlp.dense_h_to_4h.weight: Rank = 512
# Step step9000 Layer gpt_neox.layers.0.mlp.dense_h_to_4h.bias: Rank = 1
# Step step9000 Layer gpt_neox.layers.0.mlp.dense_4h_to_h.weight: Rank = 512
# Step step9000 Layer gpt_neox.layers.0.mlp.dense_4h_to_h.bias: Rank = 1
# Step step9000 Layer gpt_neox.layers.1.input_layernorm.weight: Rank = 1
# Step step9000 Layer gpt_neox.layers.1.input_layernorm.bias: Rank = 1
# Step step9000 Layer gpt_neox.layers.1.post_attention_layernorm.weight: Rank = 1
# Step step9000 Layer gpt_neox.layers.1.post_attention_layernorm.bias: Rank = 1
# Step step9000 Layer gpt_neox.layers.1.attention.query_key_value.weight: Rank = 512
# ...
# Step step25000 Layer gpt_neox.layers.4.post_attention_layernorm.weight: Rank = 1
# Step step25000 Layer gpt_neox.layers.4.post_attention_layernorm.bias: Rank = 1
# Step step25000 Layer gpt_neox.layers.4.attention.query_key_value.weight: Rank = 512
# Step step25000 Layer gpt_neox.layers.4.attention.query_key_value.bias: Rank = 1
# Step step25000 Layer gpt_neox.layers.4.attention.dense.weight: Rank = 512
# Step step25000 Layer gpt_neox.layers.4.attention.dense.bias: Rank = 1
# Step step25000 Layer gpt_neox.layers.4.mlp.dense_h_to_4h.weight: Rank = 512
# Step step25000 Layer gpt_neox.layers.4.mlp.dense_h_to_4h.bias: Rank = 1
# Step step25000 Layer gpt_neox.layers.4.mlp.dense_4h_to_h.weight: Rank = 512
# Step step25000 Layer gpt_neox.layers.4.mlp.dense_4h_to_h.bias: Rank = 1
# Step step25000 Layer gpt_neox.layers.5.input_layernorm.weight: Rank = 1
# Step step25000 Layer gpt_neox.layers.5.input_layernorm.bias: Rank = 1
# Step step25000 Layer gpt_neox.layers.5.post_attention_layernorm.weight: Rank = 1
# Step step25000 Layer gpt_neox.layers.5.post_attention_layernorm.bias: Rank = 1
# Step step25000 Layer gpt_neox.layers.5.attention.query_key_value.weight: Rank = 512
# Step step25000 Layer gpt_neox.layers.5.attention.query_key_value.bias: Rank = 1
# Step step25000 Layer gpt_neox.layers.5.attention.dense.weight: Rank = 511
# Step step25000 Layer gpt_neox.layers.5.attention.dense.bias: Rank = 1
# Step step25000 Layer gpt_neox.layers.5.mlp.dense_h_to_4h.weight: Rank = 512
# Step step25000 Layer gpt_neox.layers.5.mlp.dense_h_to_4h.bias: Rank = 1
# Step step25000 Layer gpt_neox.layers.5.mlp.dense_4h_to_h.weight: Rank = 512
# Step step25000 Layer gpt_neox.layers.5.mlp.dense_4h_to_h.bias: Rank = 1
# Step step25000 Layer gpt_neox.final_layer_norm.weight: Rank = 1
# Step step25000 Layer gpt_neox.final_layer_norm.bias: Rank = 1
#  17%|██████████████████████████████▏                                                                                                                                              | 25/143 [01:53<08:48,  4.48s/it]
# Step step25000 Layer embed_out.weight: Rank = 512
#  17%|██████████████████████████████▏                                                                                                                                              | 25/143 [01:54<09:01,  4.59s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 6
#       4 for step_idx in tqdm(range(num_steps), total=num_steps):
#       5     revision_id = f"step{1000*(step_idx+1)}"
# ----> 6     weight_diff_ranks[step_idx] = calculate_layer_diff_rank(step_idx, revision_id)
#
# Cell In[8], line 3, in calculate_layer_diff_rank(step_idx, rev_id)
#       2 def calculate_layer_diff_rank(step_idx,rev_id):
# ----> 3     model = GPTNeoXForCausalLM.from_pretrained( "EleutherAI/pythia-70m-deduped", revision=rev_id)
#       4     model_params = model.state_dict()
#       6     rank_dict = {}
#
# File ~/anaconda3/envs/flashroute/lib/python3.11/site-packages/transformers/modeling_utils.py:3510, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, *model_args, **kwargs)
#    3508 if model.can_generate() and pretrained_model_name_or_path is not None:
#    3509     try:
# -> 3510         model.generation_config = GenerationConfig.from_pretrained(
#    3511             pretrained_model_name_or_path,
#    3512             cache_dir=cache_dir,
#    3513             force_download=force_download,
#    3514             resume_download=resume_download,
#    3515             proxies=proxies,
#    3516             local_files_only=local_files_only,
#    3517             token=token,
#    3518             revision=revision,
#    3519             subfolder=subfolder,
#    3520             _from_auto=from_auto_class,
#    3521             _from_pipeline=from_pipeline,
#    3522             **kwargs,
#    3523         )
#    3524     except OSError:
#    3525         logger.info(
#    3526             "Generation config file not found, using a generation config created from the model config."
#    3527         )
#
# File ~/anaconda3/envs/flashroute/lib/python3.11/site-packages/transformers/generation/configuration_utils.py:711, in GenerationConfig.from_pretrained(cls, pretrained_model_name, config_file_name, cache_dir, force_download, local_files_only, token, revision, **kwargs)
#     708 configuration_file = config_file_name
#     709 try:
#     710     # Load from local folder or from cache or download from model Hub and cache
# --> 711     resolved_config_file = cached_file(
#     712         pretrained_model_name,
#     713         configuration_file,
#     714         cache_dir=cache_dir,
#     715         force_download=force_download,
#     716         proxies=proxies,
#     717         resume_download=resume_download,
#     718         local_files_only=local_files_only,
#     719         use_auth_token=token,
#     720         user_agent=user_agent,
#     721         revision=revision,
#     722         subfolder=subfolder,
#     723         _commit_hash=commit_hash,
#     724     )
#     725     commit_hash = extract_commit_hash(resolved_config_file, commit_hash)
#     726 except EnvironmentError:
#     727     # Raise any environment error raise by `cached_file`. It will have a helpful error message adapted to
#     728     # the original exception.
#
# File ~/anaconda3/envs/flashroute/lib/python3.11/site-packages/transformers/utils/hub.py:430, in cached_file(path_or_repo_id, filename, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     427 user_agent = http_user_agent(user_agent)
#     428 try:
#     429     # Load from URL or cache if already cached
# --> 430     resolved_file = hf_hub_download(
#     431         path_or_repo_id,
#     432         filename,
#     433         subfolder=None if len(subfolder) == 0 else subfolder,
#     434         repo_type=repo_type,
#     435         revision=revision,
#     436         cache_dir=cache_dir,
#     437         user_agent=user_agent,
#     438         force_download=force_download,
#     439         proxies=proxies,
#     440         resume_download=resume_download,
#     441         token=token,
#     442         local_files_only=local_files_only,
#     443     )
#     444 except GatedRepoError as e:
#     445     raise EnvironmentError(
#     446         "You are trying to access a gated repo.\nMake sure to request access at "
#     447         f"https://huggingface.co/{path_or_repo_id} and pass a token having permission to this repo either "
#     448         "by logging in with `huggingface-cli login` or by passing `token=<your_token>`."
#     449     ) from e
#
# File ~/anaconda3/envs/flashroute/lib/python3.11/site-packages/huggingface_hub/utils/_validators.py:118, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     115 if check_use_auth_token:
#     116     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 118 return fn(*args, **kwargs)
#
# File ~/anaconda3/envs/flashroute/lib/python3.11/site-packages/huggingface_hub/file_download.py:1247, in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, local_dir_use_symlinks, user_agent, force_download, force_filename, proxies, etag_timeout, resume_download, token, local_files_only, legacy_cache_layout, endpoint)
#    1245 try:
#    1246     try:
# -> 1247         metadata = get_hf_file_metadata(
#    1248             url=url,
#    1249             token=token,
#    1250             proxies=proxies,
#    1251             timeout=etag_timeout,
#    1252         )
#    1253     except EntryNotFoundError as http_error:
#    1254         # Cache the non-existence of the file and raise
#    1255         commit_hash = http_error.response.headers.get(HUGGINGFACE_HEADER_X_REPO_COMMIT)
#
# File ~/anaconda3/envs/flashroute/lib/python3.11/site-packages/huggingface_hub/utils/_validators.py:118, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     115 if check_use_auth_token:
#     116     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 118 return fn(*args, **kwargs)
#
# File ~/anaconda3/envs/flashroute/lib/python3.11/site-packages/huggingface_hub/file_download.py:1624, in get_hf_file_metadata(url, token, proxies, timeout)
#    1621 headers["Accept-Encoding"] = "identity"  # prevent any compression => we want to know the real size of the file
#    1623 # Retrieve metadata
# -> 1624 r = _request_wrapper(
#    1625     method="HEAD",
#    1626     url=url,
#    1627     headers=headers,
#    1628     allow_redirects=False,
#    1629     follow_relative_redirects=True,
#    1630     proxies=proxies,
#    1631     timeout=timeout,
#    1632 )
#    1633 hf_raise_for_status(r)
#    1635 # Return
#
# File ~/anaconda3/envs/flashroute/lib/python3.11/site-packages/huggingface_hub/file_download.py:402, in _request_wrapper(method, url, follow_relative_redirects, **params)
#     400 # 2. Force relative redirection
#     401 if follow_relative_redirects:
# --> 402     response = _request_wrapper(
#     403         method=method,
#     404         url=url,
#     405         follow_relative_redirects=False,
#     406         **params,
#     407     )
#     409     # If redirection, we redirect only relative paths.
#     410     # This is useful in case of a renamed repository.
#     411     if 300 <= response.status_code <= 399:
#
# File ~/anaconda3/envs/flashroute/lib/python3.11/site-packages/huggingface_hub/file_download.py:425, in _request_wrapper(method, url, follow_relative_redirects, **params)
#     422     return response
#     424 # Perform request and return if status_code is not in the retry list.
# --> 425 response = get_session().request(method=method, url=url, **params)
#     426 hf_raise_for_status(response)
#     427 return response
#
# File ~/anaconda3/envs/flashroute/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/anaconda3/envs/flashroute/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/anaconda3/envs/flashroute/lib/python3.11/site-packages/huggingface_hub/utils/_http.py:63, in UniqueRequestIdAdapter.send(self, request, *args, **kwargs)
#      61 """Catch any RequestException to append request id to the error message for debugging."""
#      62 try:
# ---> 63     return super().send(request, *args, **kwargs)
#      64 except requests.RequestException as e:
#      65     request_id = request.headers.get(X_AMZN_TRACE_ID)
#
# File ~/anaconda3/envs/flashroute/lib/python3.11/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File ~/anaconda3/envs/flashroute/lib/python3.11/site-packages/urllib3/connectionpool.py:715, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     712     self._prepare_proxy(conn)
#     714 # Make the request on the httplib connection object.
# --> 715 httplib_response = self._make_request(
#     716     conn,
#     717     method,
#     718     url,
#     719     timeout=timeout_obj,
#     720     body=body,
#     721     headers=headers,
#     722     chunked=chunked,
#     723 )
#     725 # If we're going to release the connection in ``finally:``, then
#     726 # the response doesn't need to know about the connection. Otherwise
#     727 # it will also try to release it and we'll have a double-release
#     728 # mess.
#     729 response_conn = conn if not release_conn else None
#
# File ~/anaconda3/envs/flashroute/lib/python3.11/site-packages/urllib3/connectionpool.py:467, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     462             httplib_response = conn.getresponse()
#     463         except BaseException as e:
#     464             # Remove the TypeError from the exception chain in
#     465             # Python 3 (including for exceptions like SystemExit).
#     466             # Otherwise it looks like a bug in the code.
# --> 467             six.raise_from(e, None)
#     468 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     469     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/anaconda3/envs/flashroute/lib/python3.11/site-packages/urllib3/connectionpool.py:462, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     459 except TypeError:
#     460     # Python 3
#     461     try:
# --> 462         httplib_response = conn.getresponse()
#     463     except BaseException as e:
#     464         # Remove the TypeError from the exception chain in
#     465         # Python 3 (including for exceptions like SystemExit).
#     466         # Otherwise it looks like a bug in the code.
#     467         six.raise_from(e, None)
#
# File ~/anaconda3/envs/flashroute/lib/python3.11/http/client.py:1378, in HTTPConnection.getresponse(self)
#    1376 try:
#    1377     try:
# -> 1378         response.begin()
#    1379     except ConnectionError:
#    1380         self.close()
#
# File ~/anaconda3/envs/flashroute/lib/python3.11/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~/anaconda3/envs/flashroute/lib/python3.11/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~/anaconda3/envs/flashroute/lib/python3.11/socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File ~/anaconda3/envs/flashroute/lib/python3.11/ssl.py:1311, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1307     if flags != 0:
#    1308         raise ValueError(
#    1309           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1310           self.__class__)
# -> 1311     return self.read(nbytes, buffer)
#    1312 else:
#    1313     return super().recv_into(buffer, nbytes, flags)
#
# File ~/anaconda3/envs/flashroute/lib/python3.11/ssl.py:1167, in SSLSocket.read(self, len, buffer)
#    1165 try:
#    1166     if buffer is not None:
# -> 1167         return self._sslobj.read(len, buffer)
#    1168     else:
#    1169         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
with open('pythia_70m_layer_diff_rank.pickle', 'wb') as file:
    pickle.dump(step_dists, file)

# %%
# Distance form the last-epoch's layer's weights vs current-epcoh's

# %%
plot_data = []
for epoch, layers in step_dists.items():
    for layer, distance in layers.items():
        plot_data.append({'Epoch': int(epoch), 'Layer': layer, 'Distance': distance})

# Creating a DataFrame from the structured data
df = pd.DataFrame(plot_data)

# Sorting the DataFrame by Epoch for better plotting
df.sort_values(by='Epoch', inplace=True)

# Setting up the plot style
sns.set(style="whitegrid")

# Creating the plot
plt.figure(figsize=(30, 16))

# Plotting a line for each layer
for layer in list(ref_model_params.keys()):
    if "rotary_emb.inv_freq" not in layer:
        sns.lineplot(data=df[df['Layer'] == layer], x='Epoch', y='Distance', label=layer)

# Adding plot labels and title
plt.xlabel('Epoch')
plt.ylabel('Distance')
plt.title('Distance by Layer over Different Epochs')
plt.legend(title='Layers', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %%
# Distance form the last-epoch's layer's weights vs current-epcoh's (log-scale)

# %%
# Setting up the plot style
sns.set(style="whitegrid")

# Creating the plot
plt.figure(figsize=(30, 16))

# Dictionary to store slope data for each layer
slope_data = {'Layer': [], 'Slope': []}

# Plotting a line for each layer
for layer in list(ref_model_params.keys()):
    if ("rotary_emb.inv_freq" not in layer) and ("bias" not in layer):
        layer_data = df[df['Layer'] == layer]
        sns.lineplot(data=layer_data, x='Epoch', y='Distance', label=layer)

        # Calculating the slope using linear regression
        x = layer_data['Epoch']
        y = layer_data['Distance']
        slope, intercept = np.polyfit(x, y, 1)

        # Adding slope data to the dictionary
        slope_data['Layer'].append(layer)
        slope_data['Slope'].append(slope)

# Adding plot labels and title
plt.xlabel('Epoch')
plt.ylabel('Distance (log scale)')
plt.yscale('log')  # Set y-axis to logarithmic scale
plt.title('Distance by Layer over Different Epochs')
plt.legend(title='Layers', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %%
# Creating a DataFrame for the slope data
slope_df = pd.DataFrame(slope_data)

# Displaying the slope data
print("Slope Data:")
print(slope_df)
