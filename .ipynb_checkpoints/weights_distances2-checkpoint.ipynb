# %% [markdown]
# # Weights Distances

# %%
######################## (70m) ############################

# %%
from tqdm import tqdm
from transformers import GPTNeoXForCausalLM, AutoTokenizer
import concurrent.futures
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pickle
import seaborn as sns



tokenizer = AutoTokenizer.from_pretrained( "EleutherAI/pythia-70m-deduped", revision="step143000" )
ref_model = GPTNeoXForCausalLM.from_pretrained( "EleutherAI/pythia-70m-deduped", revision="step143000")
ref_model_params = ref_model.state_dict()

# %%
# Define the function to calculate layer distances
def calculate_layer_distances(step_idx,rev_id):
    model = GPTNeoXForCausalLM.from_pretrained( "EleutherAI/pythia-70m-deduped", revision=rev_id)
    model_params = model.state_dict()
        
    layer_dists = {}
    
    for layer in list(model_params.keys()):
        # Extract weights for the current layer
        weights_model = model_params[layer]
        weights_ref_model = ref_model_params[layer]

        # Calculate Euclidean distance (you can replace this with other metrics)
        euclidean_distance = (weights_model - weights_ref_model).norm().item()
        layer_dists[layer] = euclidean_distance
        print(f"Step {rev_id} Layer {layer}: Euclidean Distance = {euclidean_distance}")

    del model
    return layer_dists

# Set the number of steps and the number of steps to process simultaneously
num_steps = 143  # Adjust this according to your actual number of steps

# %%
# since the distance is majorly in the first and last layers, should we apply layerwise learning rates ?3
# the overall "loss" is sum of individial layer-losses
# so, from the plots of layerwise distances it can be seen which layer has a steep-decrease in distance and which layer does'nt 
# this can be used for layerwise finetuning ?

# %%
step_dists = {}

with concurrent.futures.ThreadPoolExecutor() as executor:
    # Using ThreadPoolExecutor to parallelize the loop
    futures = {executor.submit(calculate_layer_distances, step_idx, f"step{1000*(step_idx+1)}"): step_idx for step_idx in range(num_steps)}

    for future in tqdm(concurrent.futures.as_completed(futures), total=len(futures)):
        step_idx = futures[future]
        revision_id = f"step{1000*(step_idx+1)}"
        step_dists[step_idx] = future.result()
# Out:
#   0%|                                                                                                                                                                                      | 0/143 [00:00<?, ?it/s]
# pytorch_model.bin:   0%|          | 0.00/166M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/166M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/166M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/166M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/166M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/166M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/166M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/166M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/166M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/166M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/166M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/166M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/166M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/166M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/166M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/166M [00:00<?, ?B/s]
#   1%|█▏                                                                                                                                                                          | 1/143 [01:37<3:51:18, 97.73s/it]
# Step step13000 Layer gpt_neox.embed_in.weight: Euclidean Distance = 273.5267639160156
# Step step13000 Layer gpt_neox.layers.0.input_layernorm.weight: Euclidean Distance = 4.015206336975098
# Step step13000 Layer gpt_neox.layers.0.input_layernorm.bias: Euclidean Distance = 4.489306926727295
# Step step13000 Layer gpt_neox.layers.0.post_attention_layernorm.weight: Euclidean Distance = 2.102649211883545
# Step step13000 Layer gpt_neox.layers.0.post_attention_layernorm.bias: Euclidean Distance = 1.2717159986495972
# Step step13000 Layer gpt_neox.layers.0.attention.query_key_value.weight: Euclidean Distance = 30.943649291992188
# Step step13000 Layer gpt_neox.layers.0.attention.query_key_value.bias: Euclidean Distance = 74.43865203857422
# Step step13000 Layer gpt_neox.layers.0.attention.dense.weight: Euclidean Distance = 13.900260925292969
# Step step13000 Layer gpt_neox.layers.0.attention.dense.bias: Euclidean Distance = 1.6547363996505737
# Step step13000 Layer gpt_neox.layers.0.mlp.dense_h_to_4h.weight: Euclidean Distance = 37.566917419433594
# Step step13000 Layer gpt_neox.layers.0.mlp.dense_h_to_4h.bias: Euclidean Distance = 3.888367176055908
# Step step13000 Layer gpt_neox.layers.0.mlp.dense_4h_to_h.weight: Euclidean Distance = 27.050033569335938
# Step step13000 Layer gpt_neox.layers.0.mlp.dense_4h_to_h.bias: Euclidean Distance = 1.6547363996505737
# Step step13000 Layer gpt_neox.layers.1.input_layernorm.weight: Euclidean Distance = 4.42836332321167
# Step step13000 Layer gpt_neox.layers.1.input_layernorm.bias: Euclidean Distance = 1.6899842023849487
# Step step13000 Layer gpt_neox.layers.1.post_attention_layernorm.weight: Euclidean Distance = 6.185909748077393
# Step step13000 Layer gpt_neox.layers.1.post_attention_layernorm.bias: Euclidean Distance = 2.7787725925445557
# Step step13000 Layer gpt_neox.layers.1.attention.query_key_value.weight: Euclidean Distance = 35.153202056884766
# Step step13000 Layer gpt_neox.layers.1.attention.query_key_value.bias: Euclidean Distance = 125.88520812988281
# Step step13000 Layer gpt_neox.layers.1.attention.dense.weight: Euclidean Distance = 14.154930114746094
# Step step13000 Layer gpt_neox.layers.1.attention.dense.bias: Euclidean Distance = 0.8905248641967773
# Step step13000 Layer gpt_neox.layers.1.mlp.dense_h_to_4h.weight: Euclidean Distance = 40.548851013183594
# Step step13000 Layer gpt_neox.layers.1.mlp.dense_h_to_4h.bias: Euclidean Distance = 7.11582612991333
# Step step13000 Layer gpt_neox.layers.1.mlp.dense_4h_to_h.weight: Euclidean Distance = 28.066593170166016
# Step step13000 Layer gpt_neox.layers.1.mlp.dense_4h_to_h.bias: Euclidean Distance = 0.8905248641967773
# Step step13000 Layer gpt_neox.layers.2.input_layernorm.weight: Euclidean Distance = 3.4463796615600586
# Step step13000 Layer gpt_neox.layers.2.input_layernorm.bias: Euclidean Distance = 2.3140268325805664
# Step step13000 Layer gpt_neox.layers.2.post_attention_layernorm.weight: Euclidean Distance = 2.829777956008911
# Step step13000 Layer gpt_neox.layers.2.post_attention_layernorm.bias: Euclidean Distance = 2.4955694675445557
# Step step13000 Layer gpt_neox.layers.2.attention.query_key_value.weight: Euclidean Distance = 33.56409454345703
# Step step13000 Layer gpt_neox.layers.2.attention.query_key_value.bias: Euclidean Distance = 190.302490234375
# Step step13000 Layer gpt_neox.layers.2.attention.dense.weight: Euclidean Distance = 15.062335968017578
# Step step13000 Layer gpt_neox.layers.2.attention.dense.bias: Euclidean Distance = 0.9380225539207458
# Step step13000 Layer gpt_neox.layers.2.mlp.dense_h_to_4h.weight: Euclidean Distance = 38.24502182006836
# Step step13000 Layer gpt_neox.layers.2.mlp.dense_h_to_4h.bias: Euclidean Distance = 8.948809623718262
# Step step13000 Layer gpt_neox.layers.2.mlp.dense_4h_to_h.weight: Euclidean Distance = 30.44066047668457
# Step step13000 Layer gpt_neox.layers.2.mlp.dense_4h_to_h.bias: Euclidean Distance = 0.9380225539207458
# Step step13000 Layer gpt_neox.layers.3.input_layernorm.weight: Euclidean Distance = 13.99021053314209
# Step step13000 Layer gpt_neox.layers.3.input_layernorm.bias: Euclidean Distance = 11.876139640808105
# Step step13000 Layer gpt_neox.layers.3.post_attention_layernorm.weight: Euclidean Distance = 7.21924352645874
# Step step13000 Layer gpt_neox.layers.3.post_attention_layernorm.bias: Euclidean Distance = 4.270469665527344
# Step step13000 Layer gpt_neox.layers.3.attention.query_key_value.weight: Euclidean Distance = 119.6688003540039
# Step step13000 Layer gpt_neox.layers.3.attention.query_key_value.bias: Euclidean Distance = 703.402099609375
# Step step13000 Layer gpt_neox.layers.3.attention.dense.weight: Euclidean Distance = 19.187936782836914
# Step step13000 Layer gpt_neox.layers.3.attention.dense.bias: Euclidean Distance = 1.3195735216140747
# Step step13000 Layer gpt_neox.layers.3.mlp.dense_h_to_4h.weight: Euclidean Distance = 38.20450210571289
# Step step13000 Layer gpt_neox.layers.3.mlp.dense_h_to_4h.bias: Euclidean Distance = 6.982273101806641
# Step step13000 Layer gpt_neox.layers.3.mlp.dense_4h_to_h.weight: Euclidean Distance = 38.273921966552734
# Step step13000 Layer gpt_neox.layers.3.mlp.dense_4h_to_h.bias: Euclidean Distance = 1.3195735216140747
# Step step13000 Layer gpt_neox.layers.4.input_layernorm.weight: Euclidean Distance = 37.56088638305664
# Step step13000 Layer gpt_neox.layers.4.input_layernorm.bias: Euclidean Distance = 20.319997787475586
# Step step13000 Layer gpt_neox.layers.4.post_attention_layernorm.weight: Euclidean Distance = 12.415938377380371
# Step step13000 Layer gpt_neox.layers.4.post_attention_layernorm.bias: Euclidean Distance = 5.920571804046631
# Step step13000 Layer gpt_neox.layers.4.attention.query_key_value.weight: Euclidean Distance = 179.65481567382812
# Step step13000 Layer gpt_neox.layers.4.attention.query_key_value.bias: Euclidean Distance = 767.6134033203125
# Step step13000 Layer gpt_neox.layers.4.attention.dense.weight: Euclidean Distance = 26.574459075927734
# Step step13000 Layer gpt_neox.layers.4.attention.dense.bias: Euclidean Distance = 1.4009515047073364
# Step step13000 Layer gpt_neox.layers.4.mlp.dense_h_to_4h.weight: Euclidean Distance = 38.32646942138672
# Step step13000 Layer gpt_neox.layers.4.mlp.dense_h_to_4h.bias: Euclidean Distance = 6.603878498077393
# Step step13000 Layer gpt_neox.layers.4.mlp.dense_4h_to_h.weight: Euclidean Distance = 42.643882751464844
# Step step13000 Layer gpt_neox.layers.4.mlp.dense_4h_to_h.bias: Euclidean Distance = 1.4009515047073364
# Step step13000 Layer gpt_neox.layers.5.input_layernorm.weight: Euclidean Distance = 50.886962890625
# Step step13000 Layer gpt_neox.layers.5.input_layernorm.bias: Euclidean Distance = 8.190567016601562
# Step step13000 Layer gpt_neox.layers.5.post_attention_layernorm.weight: Euclidean Distance = 10.067126274108887
# Step step13000 Layer gpt_neox.layers.5.post_attention_layernorm.bias: Euclidean Distance = 5.591922283172607
# Step step13000 Layer gpt_neox.layers.5.attention.query_key_value.weight: Euclidean Distance = 120.57738494873047
# Step step13000 Layer gpt_neox.layers.5.attention.query_key_value.bias: Euclidean Distance = 958.0750732421875
# Step step13000 Layer gpt_neox.layers.5.attention.dense.weight: Euclidean Distance = 20.126497268676758
# Step step13000 Layer gpt_neox.layers.5.attention.dense.bias: Euclidean Distance = 1.894834280014038
# Step step13000 Layer gpt_neox.layers.5.mlp.dense_h_to_4h.weight: Euclidean Distance = 38.9585075378418
# Step step13000 Layer gpt_neox.layers.5.mlp.dense_h_to_4h.bias: Euclidean Distance = 6.6437273025512695
# Step step13000 Layer gpt_neox.layers.5.mlp.dense_4h_to_h.weight: Euclidean Distance = 45.48450469970703
# Step step13000 Layer gpt_neox.layers.5.mlp.dense_4h_to_h.bias: Euclidean Distance = 1.894834280014038
# Step step13000 Layer gpt_neox.final_layer_norm.weight: Euclidean Distance = 261.2234802246094
# Step step13000 Layer gpt_neox.final_layer_norm.bias: Euclidean Distance = 207.33538818359375
# Step step13000 Layer embed_out.weight: Euclidean Distance = 721.3884887695312
# pytorch_model.bin:   0%|          | 0.00/166M [00:00<?, ?B/s]
#   1%|██▍                                                                                                                                                                         | 2/143 [01:47<1:48:20, 46.10s/it]
# Step step16000 Layer gpt_neox.embed_in.weight: Euclidean Distance = 272.931396484375
# Step step16000 Layer gpt_neox.layers.0.input_layernorm.weight: Euclidean Distance = 4.528091907501221
# Step step16000 Layer gpt_neox.layers.0.input_layernorm.bias: Euclidean Distance = 4.16194486618042
# Step step16000 Layer gpt_neox.layers.0.post_attention_layernorm.weight: Euclidean Distance = 2.1550586223602295
# Step step16000 Layer gpt_neox.layers.0.post_attention_layernorm.bias: Euclidean Distance = 1.2017978429794312
# Step step16000 Layer gpt_neox.layers.0.attention.query_key_value.weight: Euclidean Distance = 29.971752166748047
# Step step16000 Layer gpt_neox.layers.0.attention.query_key_value.bias: Euclidean Distance = 73.09539031982422
# Step step16000 Layer gpt_neox.layers.0.attention.dense.weight: Euclidean Distance = 13.505831718444824
# Step step16000 Layer gpt_neox.layers.0.attention.dense.bias: Euclidean Distance = 1.5466543436050415
# Step step16000 Layer gpt_neox.layers.0.mlp.dense_h_to_4h.weight: Euclidean Distance = 37.9110107421875
# Step step16000 Layer gpt_neox.layers.0.mlp.dense_h_to_4h.bias: Euclidean Distance = 3.7035133838653564
# Step step16000 Layer gpt_neox.layers.0.mlp.dense_4h_to_h.weight: Euclidean Distance = 26.89055824279785
# Step step16000 Layer gpt_neox.layers.0.mlp.dense_4h_to_h.bias: Euclidean Distance = 1.5466543436050415
# Step step16000 Layer gpt_neox.layers.1.input_layernorm.weight: Euclidean Distance = 4.650021553039551
# Step step16000 Layer gpt_neox.layers.1.input_layernorm.bias: Euclidean Distance = 1.6001121997833252
# Step step16000 Layer gpt_neox.layers.1.post_attention_layernorm.weight: Euclidean Distance = 6.142703056335449
# Step step16000 Layer gpt_neox.layers.1.post_attention_layernorm.bias: Euclidean Distance = 2.5959107875823975
# Step step16000 Layer gpt_neox.layers.1.attention.query_key_value.weight: Euclidean Distance = 34.6349983215332
# Step step16000 Layer gpt_neox.layers.1.attention.query_key_value.bias: Euclidean Distance = 122.90096282958984
# Step step16000 Layer gpt_neox.layers.1.attention.dense.weight: Euclidean Distance = 13.834297180175781
# Step step16000 Layer gpt_neox.layers.1.attention.dense.bias: Euclidean Distance = 0.8300307393074036
# Step step16000 Layer gpt_neox.layers.1.mlp.dense_h_to_4h.weight: Euclidean Distance = 40.03208541870117
# Step step16000 Layer gpt_neox.layers.1.mlp.dense_h_to_4h.bias: Euclidean Distance = 6.73101806640625
# Step step16000 Layer gpt_neox.layers.1.mlp.dense_4h_to_h.weight: Euclidean Distance = 27.515396118164062
# Step step16000 Layer gpt_neox.layers.1.mlp.dense_4h_to_h.bias: Euclidean Distance = 0.8300307393074036
# Step step16000 Layer gpt_neox.layers.2.input_layernorm.weight: Euclidean Distance = 3.748317241668701
# Step step16000 Layer gpt_neox.layers.2.input_layernorm.bias: Euclidean Distance = 2.20111083984375
# Step step16000 Layer gpt_neox.layers.2.post_attention_layernorm.weight: Euclidean Distance = 2.7558131217956543
# Step step16000 Layer gpt_neox.layers.2.post_attention_layernorm.bias: Euclidean Distance = 2.342276096343994
# Step step16000 Layer gpt_neox.layers.2.attention.query_key_value.weight: Euclidean Distance = 33.225337982177734
# Step step16000 Layer gpt_neox.layers.2.attention.query_key_value.bias: Euclidean Distance = 185.86900329589844
# Step step16000 Layer gpt_neox.layers.2.attention.dense.weight: Euclidean Distance = 14.845919609069824
# Step step16000 Layer gpt_neox.layers.2.attention.dense.bias: Euclidean Distance = 0.8831405639648438
# Step step16000 Layer gpt_neox.layers.2.mlp.dense_h_to_4h.weight: Euclidean Distance = 37.77012634277344
# Step step16000 Layer gpt_neox.layers.2.mlp.dense_h_to_4h.bias: Euclidean Distance = 8.533576965332031
# Step step16000 Layer gpt_neox.layers.2.mlp.dense_4h_to_h.weight: Euclidean Distance = 29.880020141601562
# Step step16000 Layer gpt_neox.layers.2.mlp.dense_4h_to_h.bias: Euclidean Distance = 0.8831405639648438
# Step step16000 Layer gpt_neox.layers.3.input_layernorm.weight: Euclidean Distance = 13.896434783935547
# Step step16000 Layer gpt_neox.layers.3.input_layernorm.bias: Euclidean Distance = 11.6671724319458
# Step step16000 Layer gpt_neox.layers.3.post_attention_layernorm.weight: Euclidean Distance = 7.521344184875488
# Step step16000 Layer gpt_neox.layers.3.post_attention_layernorm.bias: Euclidean Distance = 4.159055233001709
# Step step16000 Layer gpt_neox.layers.3.attention.query_key_value.weight: Euclidean Distance = 119.29853057861328
# Step step16000 Layer gpt_neox.layers.3.attention.query_key_value.bias: Euclidean Distance = 679.8170776367188
# Step step16000 Layer gpt_neox.layers.3.attention.dense.weight: Euclidean Distance = 18.824588775634766
# Step step16000 Layer gpt_neox.layers.3.attention.dense.bias: Euclidean Distance = 1.2401899099349976
# Step step16000 Layer gpt_neox.layers.3.mlp.dense_h_to_4h.weight: Euclidean Distance = 37.844200134277344
# Step step16000 Layer gpt_neox.layers.3.mlp.dense_h_to_4h.bias: Euclidean Distance = 6.67118501663208
# Step step16000 Layer gpt_neox.layers.3.mlp.dense_4h_to_h.weight: Euclidean Distance = 37.63844299316406
# Step step16000 Layer gpt_neox.layers.3.mlp.dense_4h_to_h.bias: Euclidean Distance = 1.2401899099349976
# Step step16000 Layer gpt_neox.layers.4.input_layernorm.weight: Euclidean Distance = 37.286983489990234
# Step step16000 Layer gpt_neox.layers.4.input_layernorm.bias: Euclidean Distance = 20.22080421447754
# Step step16000 Layer gpt_neox.layers.4.post_attention_layernorm.weight: Euclidean Distance = 12.724441528320312
# Step step16000 Layer gpt_neox.layers.4.post_attention_layernorm.bias: Euclidean Distance = 5.836391925811768
# Step step16000 Layer gpt_neox.layers.4.attention.query_key_value.weight: Euclidean Distance = 179.3404541015625
# Step step16000 Layer gpt_neox.layers.4.attention.query_key_value.bias: Euclidean Distance = 755.4857788085938
# Step step16000 Layer gpt_neox.layers.4.attention.dense.weight: Euclidean Distance = 27.091289520263672
# Step step16000 Layer gpt_neox.layers.4.attention.dense.bias: Euclidean Distance = 1.299977421760559
# Step step16000 Layer gpt_neox.layers.4.mlp.dense_h_to_4h.weight: Euclidean Distance = 38.168495178222656
# Step step16000 Layer gpt_neox.layers.4.mlp.dense_h_to_4h.bias: Euclidean Distance = 6.263357162475586
# Step step16000 Layer gpt_neox.layers.4.mlp.dense_4h_to_h.weight: Euclidean Distance = 42.12321090698242
# Step step16000 Layer gpt_neox.layers.4.mlp.dense_4h_to_h.bias: Euclidean Distance = 1.299977421760559
# Step step16000 Layer gpt_neox.layers.5.input_layernorm.weight: Euclidean Distance = 50.60553741455078
# Step step16000 Layer gpt_neox.layers.5.input_layernorm.bias: Euclidean Distance = 8.13967514038086
# Step step16000 Layer gpt_neox.layers.5.post_attention_layernorm.weight: Euclidean Distance = 9.903034210205078
# Step step16000 Layer gpt_neox.layers.5.post_attention_layernorm.bias: Euclidean Distance = 5.4445624351501465
# Step step16000 Layer gpt_neox.layers.5.attention.query_key_value.weight: Euclidean Distance = 119.3919906616211
# Step step16000 Layer gpt_neox.layers.5.attention.query_key_value.bias: Euclidean Distance = 926.3123168945312
# Step step16000 Layer gpt_neox.layers.5.attention.dense.weight: Euclidean Distance = 20.396162033081055
# Step step16000 Layer gpt_neox.layers.5.attention.dense.bias: Euclidean Distance = 1.8621604442596436
# Step step16000 Layer gpt_neox.layers.5.mlp.dense_h_to_4h.weight: Euclidean Distance = 38.4541130065918
# Step step16000 Layer gpt_neox.layers.5.mlp.dense_h_to_4h.bias: Euclidean Distance = 6.302473545074463
# Step step16000 Layer gpt_neox.layers.5.mlp.dense_4h_to_h.weight: Euclidean Distance = 44.973270416259766
# Step step16000 Layer gpt_neox.layers.5.mlp.dense_4h_to_h.bias: Euclidean Distance = 1.8621604442596436
# Step step16000 Layer gpt_neox.final_layer_norm.weight: Euclidean Distance = 259.2631530761719
# Step step16000 Layer gpt_neox.final_layer_norm.bias: Euclidean Distance = 207.35069274902344
# Step step16000 Layer embed_out.weight: Euclidean Distance = 717.2554931640625
# pytorch_model.bin:   0%|          | 0.00/166M [00:00<?, ?B/s]
#   2%|███▌                                                                                                                                                                        | 3/143 [02:21<1:34:55, 40.68s/it]
# Step step6000 Layer gpt_neox.embed_in.weight: Euclidean Distance = 254.92550659179688
# Step step6000 Layer gpt_neox.layers.0.input_layernorm.weight: Euclidean Distance = 2.4641687870025635
# Step step6000 Layer gpt_neox.layers.0.input_layernorm.bias: Euclidean Distance = 5.491636753082275
# Step step6000 Layer gpt_neox.layers.0.post_attention_layernorm.weight: Euclidean Distance = 5.758944988250732
# Step step6000 Layer gpt_neox.layers.0.post_attention_layernorm.bias: Euclidean Distance = 1.3270764350891113
# Step step6000 Layer gpt_neox.layers.0.attention.query_key_value.weight: Euclidean Distance = 33.86932373046875
# Step step6000 Layer gpt_neox.layers.0.attention.query_key_value.bias: Euclidean Distance = 77.47471618652344
# Step step6000 Layer gpt_neox.layers.0.attention.dense.weight: Euclidean Distance = 14.0899019241333
# Step step6000 Layer gpt_neox.layers.0.attention.dense.bias: Euclidean Distance = 2.013460636138916
# Step step6000 Layer gpt_neox.layers.0.mlp.dense_h_to_4h.weight: Euclidean Distance = 36.043907165527344
# Step step6000 Layer gpt_neox.layers.0.mlp.dense_h_to_4h.bias: Euclidean Distance = 4.356607437133789
# Step step6000 Layer gpt_neox.layers.0.mlp.dense_4h_to_h.weight: Euclidean Distance = 26.384658813476562
# Step step6000 Layer gpt_neox.layers.0.mlp.dense_4h_to_h.bias: Euclidean Distance = 2.013460636138916
# Step step6000 Layer gpt_neox.layers.1.input_layernorm.weight: Euclidean Distance = 3.842987060546875
# Step step6000 Layer gpt_neox.layers.1.input_layernorm.bias: Euclidean Distance = 1.896610975265503
# Step step6000 Layer gpt_neox.layers.1.post_attention_layernorm.weight: Euclidean Distance = 5.839925289154053
# Step step6000 Layer gpt_neox.layers.1.post_attention_layernorm.bias: Euclidean Distance = 3.2701752185821533
# Step step6000 Layer gpt_neox.layers.1.attention.query_key_value.weight: Euclidean Distance = 35.821746826171875
# Step step6000 Layer gpt_neox.layers.1.attention.query_key_value.bias: Euclidean Distance = 133.1327667236328
# Step step6000 Layer gpt_neox.layers.1.attention.dense.weight: Euclidean Distance = 14.24954605102539
# Step step6000 Layer gpt_neox.layers.1.attention.dense.bias: Euclidean Distance = 1.0572130680084229
# Step step6000 Layer gpt_neox.layers.1.mlp.dense_h_to_4h.weight: Euclidean Distance = 40.17494201660156
# Step step6000 Layer gpt_neox.layers.1.mlp.dense_h_to_4h.bias: Euclidean Distance = 8.057831764221191
# Step step6000 Layer gpt_neox.layers.1.mlp.dense_4h_to_h.weight: Euclidean Distance = 27.773361206054688
# Step step6000 Layer gpt_neox.layers.1.mlp.dense_4h_to_h.bias: Euclidean Distance = 1.0572130680084229
# Step step6000 Layer gpt_neox.layers.2.input_layernorm.weight: Euclidean Distance = 2.8398690223693848
# Step step6000 Layer gpt_neox.layers.2.input_layernorm.bias: Euclidean Distance = 2.5787904262542725
# Step step6000 Layer gpt_neox.layers.2.post_attention_layernorm.weight: Euclidean Distance = 3.08491849899292
# Step step6000 Layer gpt_neox.layers.2.post_attention_layernorm.bias: Euclidean Distance = 2.9658901691436768
# Step step6000 Layer gpt_neox.layers.2.attention.query_key_value.weight: Euclidean Distance = 33.973838806152344
# Step step6000 Layer gpt_neox.layers.2.attention.query_key_value.bias: Euclidean Distance = 200.1921844482422
# Step step6000 Layer gpt_neox.layers.2.attention.dense.weight: Euclidean Distance = 14.747760772705078
# Step step6000 Layer gpt_neox.layers.2.attention.dense.bias: Euclidean Distance = 1.1198230981826782
# Step step6000 Layer gpt_neox.layers.2.mlp.dense_h_to_4h.weight: Euclidean Distance = 39.073116302490234
# Step step6000 Layer gpt_neox.layers.2.mlp.dense_h_to_4h.bias: Euclidean Distance = 9.948930740356445
# Step step6000 Layer gpt_neox.layers.2.mlp.dense_4h_to_h.weight: Euclidean Distance = 30.22332191467285
# Step step6000 Layer gpt_neox.layers.2.mlp.dense_4h_to_h.bias: Euclidean Distance = 1.1198230981826782
# Step step6000 Layer gpt_neox.layers.3.input_layernorm.weight: Euclidean Distance = 14.511941909790039
# Step step6000 Layer gpt_neox.layers.3.input_layernorm.bias: Euclidean Distance = 12.534990310668945
# Step step6000 Layer gpt_neox.layers.3.post_attention_layernorm.weight: Euclidean Distance = 6.292262077331543
# Step step6000 Layer gpt_neox.layers.3.post_attention_layernorm.bias: Euclidean Distance = 4.660674571990967
# Step step6000 Layer gpt_neox.layers.3.attention.query_key_value.weight: Euclidean Distance = 120.67274475097656
# Step step6000 Layer gpt_neox.layers.3.attention.query_key_value.bias: Euclidean Distance = 756.2489013671875
# Step step6000 Layer gpt_neox.layers.3.attention.dense.weight: Euclidean Distance = 19.184846878051758
# Step step6000 Layer gpt_neox.layers.3.attention.dense.bias: Euclidean Distance = 1.567629098892212
# Step step6000 Layer gpt_neox.layers.3.mlp.dense_h_to_4h.weight: Euclidean Distance = 38.3507080078125
# Step step6000 Layer gpt_neox.layers.3.mlp.dense_h_to_4h.bias: Euclidean Distance = 7.72015905380249
# Step step6000 Layer gpt_neox.layers.3.mlp.dense_4h_to_h.weight: Euclidean Distance = 37.53060531616211
# Step step6000 Layer gpt_neox.layers.3.mlp.dense_4h_to_h.bias: Euclidean Distance = 1.567629098892212
# Step step6000 Layer gpt_neox.layers.4.input_layernorm.weight: Euclidean Distance = 38.821510314941406
# Step step6000 Layer gpt_neox.layers.4.input_layernorm.bias: Euclidean Distance = 20.568273544311523
# Step step6000 Layer gpt_neox.layers.4.post_attention_layernorm.weight: Euclidean Distance = 11.367164611816406
# Step step6000 Layer gpt_neox.layers.4.post_attention_layernorm.bias: Euclidean Distance = 6.220602035522461
# Step step6000 Layer gpt_neox.layers.4.attention.query_key_value.weight: Euclidean Distance = 180.60592651367188
# Step step6000 Layer gpt_neox.layers.4.attention.query_key_value.bias: Euclidean Distance = 795.0055541992188
# Step step6000 Layer gpt_neox.layers.4.attention.dense.weight: Euclidean Distance = 22.03496742248535
# Step step6000 Layer gpt_neox.layers.4.attention.dense.bias: Euclidean Distance = 1.774791955947876
# Step step6000 Layer gpt_neox.layers.4.mlp.dense_h_to_4h.weight: Euclidean Distance = 37.76154327392578
# Step step6000 Layer gpt_neox.layers.4.mlp.dense_h_to_4h.bias: Euclidean Distance = 7.415228366851807
# Step step6000 Layer gpt_neox.layers.4.mlp.dense_4h_to_h.weight: Euclidean Distance = 40.8868522644043
# Step step6000 Layer gpt_neox.layers.4.mlp.dense_4h_to_h.bias: Euclidean Distance = 1.774791955947876
# Step step6000 Layer gpt_neox.layers.5.input_layernorm.weight: Euclidean Distance = 51.770267486572266
# Step step6000 Layer gpt_neox.layers.5.input_layernorm.bias: Euclidean Distance = 8.305459022521973
# Step step6000 Layer gpt_neox.layers.5.post_attention_layernorm.weight: Euclidean Distance = 10.949776649475098
# Step step6000 Layer gpt_neox.layers.5.post_attention_layernorm.bias: Euclidean Distance = 6.005096435546875
# Step step6000 Layer gpt_neox.layers.5.attention.query_key_value.weight: Euclidean Distance = 122.7293472290039
# Step step6000 Layer gpt_neox.layers.5.attention.query_key_value.bias: Euclidean Distance = 1020.6962280273438
# Step step6000 Layer gpt_neox.layers.5.attention.dense.weight: Euclidean Distance = 17.227588653564453
# Step step6000 Layer gpt_neox.layers.5.attention.dense.bias: Euclidean Distance = 1.994179129600525
# Step step6000 Layer gpt_neox.layers.5.mlp.dense_h_to_4h.weight: Euclidean Distance = 39.08474349975586
# Step step6000 Layer gpt_neox.layers.5.mlp.dense_h_to_4h.bias: Euclidean Distance = 7.541024684906006
# Step step6000 Layer gpt_neox.layers.5.mlp.dense_4h_to_h.weight: Euclidean Distance = 44.10565948486328
# Step step6000 Layer gpt_neox.layers.5.mlp.dense_4h_to_h.bias: Euclidean Distance = 1.994179129600525
# Step step6000 Layer gpt_neox.final_layer_norm.weight: Euclidean Distance = 267.5970764160156
# Step step6000 Layer gpt_neox.final_layer_norm.bias: Euclidean Distance = 207.31478881835938
# Step step6000 Layer embed_out.weight: Euclidean Distance = 731.0535888671875
# pytorch_model.bin:   0%|          | 0.00/166M [00:00<?, ?B/s]
#   3%|████▊                                                                                                                                                                       | 4/143 [02:30<1:04:28, 27.83s/it]
# Step step14000 Layer gpt_neox.embed_in.weight: Euclidean Distance = 273.647216796875
# Step step14000 Layer gpt_neox.layers.0.input_layernorm.weight: Euclidean Distance = 4.211747646331787
# Step step14000 Layer gpt_neox.layers.0.input_layernorm.bias: Euclidean Distance = 4.375204086303711
# Step step14000 Layer gpt_neox.layers.0.post_attention_layernorm.weight: Euclidean Distance = 2.070387840270996
# Step step14000 Layer gpt_neox.layers.0.post_attention_layernorm.bias: Euclidean Distance = 1.2492040395736694
# Step step14000 Layer gpt_neox.layers.0.attention.query_key_value.weight: Euclidean Distance = 30.590288162231445
# Step step14000 Layer gpt_neox.layers.0.attention.query_key_value.bias: Euclidean Distance = 74.00431823730469
# Step step14000 Layer gpt_neox.layers.0.attention.dense.weight: Euclidean Distance = 13.753132820129395
# Step step14000 Layer gpt_neox.layers.0.attention.dense.bias: Euclidean Distance = 1.6174139976501465
# Step step14000 Layer gpt_neox.layers.0.mlp.dense_h_to_4h.weight: Euclidean Distance = 37.70350646972656
# Step step14000 Layer gpt_neox.layers.0.mlp.dense_h_to_4h.bias: Euclidean Distance = 3.8255770206451416
# Step step14000 Layer gpt_neox.layers.0.mlp.dense_4h_to_h.weight: Euclidean Distance = 27.007587432861328
# Step step14000 Layer gpt_neox.layers.0.mlp.dense_4h_to_h.bias: Euclidean Distance = 1.6174139976501465
# Step step14000 Layer gpt_neox.layers.1.input_layernorm.weight: Euclidean Distance = 4.508919715881348
# Step step14000 Layer gpt_neox.layers.1.input_layernorm.bias: Euclidean Distance = 1.6599252223968506
# Step step14000 Layer gpt_neox.layers.1.post_attention_layernorm.weight: Euclidean Distance = 6.180426597595215
# Step step14000 Layer gpt_neox.layers.1.post_attention_layernorm.bias: Euclidean Distance = 2.7154622077941895
# Step step14000 Layer gpt_neox.layers.1.attention.query_key_value.weight: Euclidean Distance = 34.99637985229492
# Step step14000 Layer gpt_neox.layers.1.attention.query_key_value.bias: Euclidean Distance = 124.89093017578125
# Step step14000 Layer gpt_neox.layers.1.attention.dense.weight: Euclidean Distance = 14.050079345703125
# Step step14000 Layer gpt_neox.layers.1.attention.dense.bias: Euclidean Distance = 0.8705547451972961
# Step step14000 Layer gpt_neox.layers.1.mlp.dense_h_to_4h.weight: Euclidean Distance = 40.40849304199219
# Step step14000 Layer gpt_neox.layers.1.mlp.dense_h_to_4h.bias: Euclidean Distance = 6.985834121704102
# Step step14000 Layer gpt_neox.layers.1.mlp.dense_4h_to_h.weight: Euclidean Distance = 27.90049171447754
# Step step14000 Layer gpt_neox.layers.1.mlp.dense_4h_to_h.bias: Euclidean Distance = 0.8705547451972961
# Step step14000 Layer gpt_neox.layers.2.input_layernorm.weight: Euclidean Distance = 3.5460524559020996
# Step step14000 Layer gpt_neox.layers.2.input_layernorm.bias: Euclidean Distance = 2.2760581970214844
# Step step14000 Layer gpt_neox.layers.2.post_attention_layernorm.weight: Euclidean Distance = 2.805671453475952
# Step step14000 Layer gpt_neox.layers.2.post_attention_layernorm.bias: Euclidean Distance = 2.442157506942749
# Step step14000 Layer gpt_neox.layers.2.attention.query_key_value.weight: Euclidean Distance = 33.4682731628418
# Step step14000 Layer gpt_neox.layers.2.attention.query_key_value.bias: Euclidean Distance = 188.81898498535156
# Step step14000 Layer gpt_neox.layers.2.attention.dense.weight: Euclidean Distance = 15.000348091125488
# Step step14000 Layer gpt_neox.layers.2.attention.dense.bias: Euclidean Distance = 0.9183244705200195
# Step step14000 Layer gpt_neox.layers.2.mlp.dense_h_to_4h.weight: Euclidean Distance = 38.099517822265625
# Step step14000 Layer gpt_neox.layers.2.mlp.dense_h_to_4h.bias: Euclidean Distance = 8.809131622314453
# Step step14000 Layer gpt_neox.layers.2.mlp.dense_4h_to_h.weight: Euclidean Distance = 30.271350860595703
# Step step14000 Layer gpt_neox.layers.2.mlp.dense_4h_to_h.bias: Euclidean Distance = 0.9183244705200195
# Step step14000 Layer gpt_neox.layers.3.input_layernorm.weight: Euclidean Distance = 13.953812599182129
# Step step14000 Layer gpt_neox.layers.3.input_layernorm.bias: Euclidean Distance = 11.802265167236328
# Step step14000 Layer gpt_neox.layers.3.post_attention_layernorm.weight: Euclidean Distance = 7.331192970275879
# Step step14000 Layer gpt_neox.layers.3.post_attention_layernorm.bias: Euclidean Distance = 4.230648517608643
# Step step14000 Layer gpt_neox.layers.3.attention.query_key_value.weight: Euclidean Distance = 119.53648376464844
# Step step14000 Layer gpt_neox.layers.3.attention.query_key_value.bias: Euclidean Distance = 695.5464477539062
# Step step14000 Layer gpt_neox.layers.3.attention.dense.weight: Euclidean Distance = 19.08101463317871
# Step step14000 Layer gpt_neox.layers.3.attention.dense.bias: Euclidean Distance = 1.2920372486114502
# Step step14000 Layer gpt_neox.layers.3.mlp.dense_h_to_4h.weight: Euclidean Distance = 38.09523391723633
# Step step14000 Layer gpt_neox.layers.3.mlp.dense_h_to_4h.bias: Euclidean Distance = 6.877387523651123
# Step step14000 Layer gpt_neox.layers.3.mlp.dense_4h_to_h.weight: Euclidean Distance = 38.0822868347168
# Step step14000 Layer gpt_neox.layers.3.mlp.dense_4h_to_h.bias: Euclidean Distance = 1.2920372486114502
# Step step14000 Layer gpt_neox.layers.4.input_layernorm.weight: Euclidean Distance = 37.456443786621094
# Step step14000 Layer gpt_neox.layers.4.input_layernorm.bias: Euclidean Distance = 20.286691665649414
# Step step14000 Layer gpt_neox.layers.4.post_attention_layernorm.weight: Euclidean Distance = 12.532049179077148
# Step step14000 Layer gpt_neox.layers.4.post_attention_layernorm.bias: Euclidean Distance = 5.890334129333496
# Step step14000 Layer gpt_neox.layers.4.attention.query_key_value.weight: Euclidean Distance = 179.5428466796875
# Step step14000 Layer gpt_neox.layers.4.attention.query_key_value.bias: Euclidean Distance = 763.5780639648438
# Step step14000 Layer gpt_neox.layers.4.attention.dense.weight: Euclidean Distance = 26.79036521911621
# Step step14000 Layer gpt_neox.layers.4.attention.dense.bias: Euclidean Distance = 1.36445951461792
# Step step14000 Layer gpt_neox.layers.4.mlp.dense_h_to_4h.weight: Euclidean Distance = 38.2975959777832
# Step step14000 Layer gpt_neox.layers.4.mlp.dense_h_to_4h.bias: Euclidean Distance = 6.491091251373291
# Step step14000 Layer gpt_neox.layers.4.mlp.dense_4h_to_h.weight: Euclidean Distance = 42.51834487915039
# Step step14000 Layer gpt_neox.layers.4.mlp.dense_4h_to_h.bias: Euclidean Distance = 1.36445951461792
# Step step14000 Layer gpt_neox.layers.5.input_layernorm.weight: Euclidean Distance = 50.79135513305664
# Step step14000 Layer gpt_neox.layers.5.input_layernorm.bias: Euclidean Distance = 8.174592971801758
# Step step14000 Layer gpt_neox.layers.5.post_attention_layernorm.weight: Euclidean Distance = 10.007950782775879
# Step step14000 Layer gpt_neox.layers.5.post_attention_layernorm.bias: Euclidean Distance = 5.540562152862549
# Step step14000 Layer gpt_neox.layers.5.attention.query_key_value.weight: Euclidean Distance = 120.19857788085938
# Step step14000 Layer gpt_neox.layers.5.attention.query_key_value.bias: Euclidean Distance = 947.7846069335938
# Step step14000 Layer gpt_neox.layers.5.attention.dense.weight: Euclidean Distance = 20.261322021484375
# Step step14000 Layer gpt_neox.layers.5.attention.dense.bias: Euclidean Distance = 1.8836086988449097
# Step step14000 Layer gpt_neox.layers.5.mlp.dense_h_to_4h.weight: Euclidean Distance = 38.805335998535156
# Step step14000 Layer gpt_neox.layers.5.mlp.dense_h_to_4h.bias: Euclidean Distance = 6.5264058113098145
# Step step14000 Layer gpt_neox.layers.5.mlp.dense_4h_to_h.weight: Euclidean Distance = 45.343631744384766
# Step step14000 Layer gpt_neox.layers.5.mlp.dense_4h_to_h.bias: Euclidean Distance = 1.8836086988449097
# Step step14000 Layer gpt_neox.final_layer_norm.weight: Euclidean Distance = 260.5296630859375
# Step step14000 Layer gpt_neox.final_layer_norm.bias: Euclidean Distance = 207.3396453857422
# Step step14000 Layer embed_out.weight: Euclidean Distance = 719.9937133789062
# pytorch_model.bin:   0%|          | 0.00/166M [00:00<?, ?B/s]
#   3%|██████                                                                                                                                                                        | 5/143 [02:38<47:42, 20.74s/it]
# Step step15000 Layer gpt_neox.embed_in.weight: Euclidean Distance = 273.4178466796875
# Step step15000 Layer gpt_neox.layers.0.input_layernorm.weight: Euclidean Distance = 4.370882511138916
# Step step15000 Layer gpt_neox.layers.0.input_layernorm.bias: Euclidean Distance = 4.26692533493042
# Step step15000 Layer gpt_neox.layers.0.post_attention_layernorm.weight: Euclidean Distance = 2.0970699787139893
# Step step15000 Layer gpt_neox.layers.0.post_attention_layernorm.bias: Euclidean Distance = 1.2263561487197876
# Step step15000 Layer gpt_neox.layers.0.attention.query_key_value.weight: Euclidean Distance = 30.28978729248047
# Step step15000 Layer gpt_neox.layers.0.attention.query_key_value.bias: Euclidean Distance = 73.53746795654297
# Step step15000 Layer gpt_neox.layers.0.attention.dense.weight: Euclidean Distance = 13.636945724487305
# Step step15000 Layer gpt_neox.layers.0.attention.dense.bias: Euclidean Distance = 1.5811591148376465
# Step step15000 Layer gpt_neox.layers.0.mlp.dense_h_to_4h.weight: Euclidean Distance = 37.82784652709961
# Step step15000 Layer gpt_neox.layers.0.mlp.dense_h_to_4h.bias: Euclidean Distance = 3.765474796295166
# Step step15000 Layer gpt_neox.layers.0.mlp.dense_4h_to_h.weight: Euclidean Distance = 26.96646499633789
# Step step15000 Layer gpt_neox.layers.0.mlp.dense_4h_to_h.bias: Euclidean Distance = 1.5811591148376465
# Step step15000 Layer gpt_neox.layers.1.input_layernorm.weight: Euclidean Distance = 4.579275131225586
# Step step15000 Layer gpt_neox.layers.1.input_layernorm.bias: Euclidean Distance = 1.6301960945129395
# Step step15000 Layer gpt_neox.layers.1.post_attention_layernorm.weight: Euclidean Distance = 6.167410850524902
# Step step15000 Layer gpt_neox.layers.1.post_attention_layernorm.bias: Euclidean Distance = 2.652653694152832
# Step step15000 Layer gpt_neox.layers.1.attention.query_key_value.weight: Euclidean Distance = 34.831268310546875
# Step step15000 Layer gpt_neox.layers.1.attention.query_key_value.bias: Euclidean Distance = 123.88875579833984
# Step step15000 Layer gpt_neox.layers.1.attention.dense.weight: Euclidean Distance = 13.94951057434082
# Step step15000 Layer gpt_neox.layers.1.attention.dense.bias: Euclidean Distance = 0.8507325053215027
# Step step15000 Layer gpt_neox.layers.1.mlp.dense_h_to_4h.weight: Euclidean Distance = 40.23772048950195
# Step step15000 Layer gpt_neox.layers.1.mlp.dense_h_to_4h.bias: Euclidean Distance = 6.857649803161621
# Step step15000 Layer gpt_neox.layers.1.mlp.dense_4h_to_h.weight: Euclidean Distance = 27.720781326293945
# Step step15000 Layer gpt_neox.layers.1.mlp.dense_4h_to_h.bias: Euclidean Distance = 0.8507325053215027
# Step step15000 Layer gpt_neox.layers.2.input_layernorm.weight: Euclidean Distance = 3.65156888961792
# Step step15000 Layer gpt_neox.layers.2.input_layernorm.bias: Euclidean Distance = 2.2385146617889404
# Step step15000 Layer gpt_neox.layers.2.post_attention_layernorm.weight: Euclidean Distance = 2.7797398567199707
# Step step15000 Layer gpt_neox.layers.2.post_attention_layernorm.bias: Euclidean Distance = 2.3927764892578125
# Step step15000 Layer gpt_neox.layers.2.attention.query_key_value.weight: Euclidean Distance = 33.355987548828125
# Step step15000 Layer gpt_neox.layers.2.attention.query_key_value.bias: Euclidean Distance = 187.37432861328125
# Step step15000 Layer gpt_neox.layers.2.attention.dense.weight: Euclidean Distance = 14.926615715026855
# Step step15000 Layer gpt_neox.layers.2.attention.dense.bias: Euclidean Distance = 0.8998332619667053
# Step step15000 Layer gpt_neox.layers.2.mlp.dense_h_to_4h.weight: Euclidean Distance = 37.951805114746094
# Step step15000 Layer gpt_neox.layers.2.mlp.dense_h_to_4h.bias: Euclidean Distance = 8.671165466308594
# Step step15000 Layer gpt_neox.layers.2.mlp.dense_4h_to_h.weight: Euclidean Distance = 30.082664489746094
# Step step15000 Layer gpt_neox.layers.2.mlp.dense_4h_to_h.bias: Euclidean Distance = 0.8998332619667053
# Step step15000 Layer gpt_neox.layers.3.input_layernorm.weight: Euclidean Distance = 13.920841217041016
# Step step15000 Layer gpt_neox.layers.3.input_layernorm.bias: Euclidean Distance = 11.733512878417969
# Step step15000 Layer gpt_neox.layers.3.post_attention_layernorm.weight: Euclidean Distance = 7.430905818939209
# Step step15000 Layer gpt_neox.layers.3.post_attention_layernorm.bias: Euclidean Distance = 4.1947855949401855
# Step step15000 Layer gpt_neox.layers.3.attention.query_key_value.weight: Euclidean Distance = 119.41425323486328
# Step step15000 Layer gpt_neox.layers.3.attention.query_key_value.bias: Euclidean Distance = 687.7400512695312
# Step step15000 Layer gpt_neox.layers.3.attention.dense.weight: Euclidean Distance = 18.95974349975586
# Step step15000 Layer gpt_neox.layers.3.attention.dense.bias: Euclidean Distance = 1.2656004428863525
# Step step15000 Layer gpt_neox.layers.3.mlp.dense_h_to_4h.weight: Euclidean Distance = 37.98080062866211
# Step step15000 Layer gpt_neox.layers.3.mlp.dense_h_to_4h.bias: Euclidean Distance = 6.774559497833252
# Step step15000 Layer gpt_neox.layers.3.mlp.dense_4h_to_h.weight: Euclidean Distance = 37.87800598144531
# Step step15000 Layer gpt_neox.layers.3.mlp.dense_4h_to_h.bias: Euclidean Distance = 1.2656004428863525
# Step step15000 Layer gpt_neox.layers.4.input_layernorm.weight: Euclidean Distance = 37.36960983276367
# Step step15000 Layer gpt_neox.layers.4.input_layernorm.bias: Euclidean Distance = 20.253753662109375
# Step step15000 Layer gpt_neox.layers.4.post_attention_layernorm.weight: Euclidean Distance = 12.629343032836914
# Step step15000 Layer gpt_neox.layers.4.post_attention_layernorm.bias: Euclidean Distance = 5.862509727478027
# Step step15000 Layer gpt_neox.layers.4.attention.query_key_value.weight: Euclidean Distance = 179.44017028808594
# Step step15000 Layer gpt_neox.layers.4.attention.query_key_value.bias: Euclidean Distance = 759.5779418945312
# Step step15000 Layer gpt_neox.layers.4.attention.dense.weight: Euclidean Distance = 26.958141326904297
# Step step15000 Layer gpt_neox.layers.4.attention.dense.bias: Euclidean Distance = 1.3299565315246582
# Step step15000 Layer gpt_neox.layers.4.mlp.dense_h_to_4h.weight: Euclidean Distance = 38.251216888427734
# Step step15000 Layer gpt_neox.layers.4.mlp.dense_h_to_4h.bias: Euclidean Distance = 6.377283096313477
# Step step15000 Layer gpt_neox.layers.4.mlp.dense_4h_to_h.weight: Euclidean Distance = 42.33832931518555
# Step step15000 Layer gpt_neox.layers.4.mlp.dense_4h_to_h.bias: Euclidean Distance = 1.3299565315246582
# Step step15000 Layer gpt_neox.layers.5.input_layernorm.weight: Euclidean Distance = 50.70040512084961
# Step step15000 Layer gpt_neox.layers.5.input_layernorm.bias: Euclidean Distance = 8.15761661529541
# Step step15000 Layer gpt_neox.layers.5.post_attention_layernorm.weight: Euclidean Distance = 9.952129364013672
# Step step15000 Layer gpt_neox.layers.5.post_attention_layernorm.bias: Euclidean Distance = 5.492645263671875
# Step step15000 Layer gpt_neox.layers.5.attention.query_key_value.weight: Euclidean Distance = 119.80581665039062
# Step step15000 Layer gpt_neox.layers.5.attention.query_key_value.bias: Euclidean Distance = 937.2880249023438
# Step step15000 Layer gpt_neox.layers.5.attention.dense.weight: Euclidean Distance = 20.3422794342041
# Step step15000 Layer gpt_neox.layers.5.attention.dense.bias: Euclidean Distance = 1.8726682662963867
# Step step15000 Layer gpt_neox.layers.5.mlp.dense_h_to_4h.weight: Euclidean Distance = 38.64147186279297
# Step step15000 Layer gpt_neox.layers.5.mlp.dense_h_to_4h.bias: Euclidean Distance = 6.41357946395874
# Step step15000 Layer gpt_neox.layers.5.mlp.dense_4h_to_h.weight: Euclidean Distance = 45.174869537353516
# Step step15000 Layer gpt_neox.layers.5.mlp.dense_4h_to_h.bias: Euclidean Distance = 1.8726682662963867
# Step step15000 Layer gpt_neox.final_layer_norm.weight: Euclidean Distance = 259.88214111328125
# Step step15000 Layer gpt_neox.final_layer_norm.bias: Euclidean Distance = 207.34486389160156
# Step step15000 Layer embed_out.weight: Euclidean Distance = 718.6136474609375
# pytorch_model.bin:   0%|          | 0.00/166M [00:00<?, ?B/s]
#   4%|███████▎                                                                                                                                                                      | 6/143 [02:40<33:07, 14.51s/it]
# Step step11000 Layer gpt_neox.embed_in.weight: Euclidean Distance = 272.0161437988281
# Step step11000 Layer gpt_neox.layers.0.input_layernorm.weight: Euclidean Distance = 3.6089377403259277
# Step step11000 Layer gpt_neox.layers.0.input_layernorm.bias: Euclidean Distance = 4.726040363311768
# Step step11000 Layer gpt_neox.layers.0.post_attention_layernorm.weight: Euclidean Distance = 2.445899486541748
# Step step11000 Layer gpt_neox.layers.0.post_attention_layernorm.bias: Euclidean Distance = 1.3112047910690308
# Step step11000 Layer gpt_neox.layers.0.attention.query_key_value.weight: Euclidean Distance = 31.622203826904297
# Step step11000 Layer gpt_neox.layers.0.attention.query_key_value.bias: Euclidean Distance = 75.31324768066406
# Step step11000 Layer gpt_neox.layers.0.attention.dense.weight: Euclidean Distance = 14.097148895263672
# Step step11000 Layer gpt_neox.layers.0.attention.dense.bias: Euclidean Distance = 1.7356832027435303
# Step step11000 Layer gpt_neox.layers.0.mlp.dense_h_to_4h.weight: Euclidean Distance = 37.150516510009766
# Step step11000 Layer gpt_neox.layers.0.mlp.dense_h_to_4h.bias: Euclidean Distance = 4.014202117919922
# Step step11000 Layer gpt_neox.layers.0.mlp.dense_4h_to_h.weight: Euclidean Distance = 27.018356323242188
# Step step11000 Layer gpt_neox.layers.0.mlp.dense_4h_to_h.bias: Euclidean Distance = 1.7356832027435303
# Step step11000 Layer gpt_neox.layers.1.input_layernorm.weight: Euclidean Distance = 4.262598991394043
# Step step11000 Layer gpt_neox.layers.1.input_layernorm.bias: Euclidean Distance = 1.7515859603881836
# Step step11000 Layer gpt_neox.layers.1.post_attention_layernorm.weight: Euclidean Distance = 6.153122425079346
# Step step11000 Layer gpt_neox.layers.1.post_attention_layernorm.bias: Euclidean Distance = 2.907266139984131
# Step step11000 Layer gpt_neox.layers.1.attention.query_key_value.weight: Euclidean Distance = 35.40859603881836
# Step step11000 Layer gpt_neox.layers.1.attention.query_key_value.bias: Euclidean Distance = 127.9364242553711
# Step step11000 Layer gpt_neox.layers.1.attention.dense.weight: Euclidean Distance = 14.31442928314209
# Step step11000 Layer gpt_neox.layers.1.attention.dense.bias: Euclidean Distance = 0.9317808151245117
# Step step11000 Layer gpt_neox.layers.1.mlp.dense_h_to_4h.weight: Euclidean Distance = 40.68830108642578
# Step step11000 Layer gpt_neox.layers.1.mlp.dense_h_to_4h.bias: Euclidean Distance = 7.3753437995910645
# Step step11000 Layer gpt_neox.layers.1.mlp.dense_4h_to_h.weight: Euclidean Distance = 28.26862907409668
# Step step11000 Layer gpt_neox.layers.1.mlp.dense_4h_to_h.bias: Euclidean Distance = 0.9317808151245117
# Step step11000 Layer gpt_neox.layers.2.input_layernorm.weight: Euclidean Distance = 3.2488808631896973
# Step step11000 Layer gpt_neox.layers.2.input_layernorm.bias: Euclidean Distance = 2.392442226409912
# Step step11000 Layer gpt_neox.layers.2.post_attention_layernorm.weight: Euclidean Distance = 2.889195680618286
# Step step11000 Layer gpt_neox.layers.2.post_attention_layernorm.bias: Euclidean Distance = 2.609985828399658
# Step step11000 Layer gpt_neox.layers.2.attention.query_key_value.weight: Euclidean Distance = 33.74213790893555
# Step step11000 Layer gpt_neox.layers.2.attention.query_key_value.bias: Euclidean Distance = 193.21592712402344
# Step step11000 Layer gpt_neox.layers.2.attention.dense.weight: Euclidean Distance = 15.124940872192383
# Step step11000 Layer gpt_neox.layers.2.attention.dense.bias: Euclidean Distance = 0.9812909364700317
# Step step11000 Layer gpt_neox.layers.2.mlp.dense_h_to_4h.weight: Euclidean Distance = 38.47308349609375
# Step step11000 Layer gpt_neox.layers.2.mlp.dense_h_to_4h.bias: Euclidean Distance = 9.231067657470703
# Step step11000 Layer gpt_neox.layers.2.mlp.dense_4h_to_h.weight: Euclidean Distance = 30.680856704711914
# Step step11000 Layer gpt_neox.layers.2.mlp.dense_4h_to_h.bias: Euclidean Distance = 0.9812909364700317
# Step step11000 Layer gpt_neox.layers.3.input_layernorm.weight: Euclidean Distance = 14.081998825073242
# Step step11000 Layer gpt_neox.layers.3.input_layernorm.bias: Euclidean Distance = 12.035839080810547
# Step step11000 Layer gpt_neox.layers.3.post_attention_layernorm.weight: Euclidean Distance = 6.965653419494629
# Step step11000 Layer gpt_neox.layers.3.post_attention_layernorm.bias: Euclidean Distance = 4.360339641571045
# Step step11000 Layer gpt_neox.layers.3.attention.query_key_value.weight: Euclidean Distance = 119.94004821777344
# Step step11000 Layer gpt_neox.layers.3.attention.query_key_value.bias: Euclidean Distance = 719.0081787109375
# Step step11000 Layer gpt_neox.layers.3.attention.dense.weight: Euclidean Distance = 19.385042190551758
# Step step11000 Layer gpt_neox.layers.3.attention.dense.bias: Euclidean Distance = 1.3794864416122437
# Step step11000 Layer gpt_neox.layers.3.mlp.dense_h_to_4h.weight: Euclidean Distance = 38.34872817993164
# Step step11000 Layer gpt_neox.layers.3.mlp.dense_h_to_4h.bias: Euclidean Distance = 7.19101619720459
# Step step11000 Layer gpt_neox.layers.3.mlp.dense_4h_to_h.weight: Euclidean Distance = 38.498477935791016
# Step step11000 Layer gpt_neox.layers.3.mlp.dense_4h_to_h.bias: Euclidean Distance = 1.3794864416122437
# Step step11000 Layer gpt_neox.layers.4.input_layernorm.weight: Euclidean Distance = 37.82112503051758
# Step step11000 Layer gpt_neox.layers.4.input_layernorm.bias: Euclidean Distance = 20.387502670288086
# Step step11000 Layer gpt_neox.layers.4.post_attention_layernorm.weight: Euclidean Distance = 12.15391731262207
# Step step11000 Layer gpt_neox.layers.4.post_attention_layernorm.bias: Euclidean Distance = 5.988973140716553
# ...
# Step step69000 Layer gpt_neox.layers.0.post_attention_layernorm.weight: Euclidean Distance = 1.7539193630218506
# Step step69000 Layer gpt_neox.layers.0.post_attention_layernorm.bias: Euclidean Distance = 0.46495023369789124
# Step step69000 Layer gpt_neox.layers.0.attention.query_key_value.weight: Euclidean Distance = 14.909076690673828
# Step step69000 Layer gpt_neox.layers.0.attention.query_key_value.bias: Euclidean Distance = 10.981670379638672
# Step step69000 Layer gpt_neox.layers.0.attention.dense.weight: Euclidean Distance = 6.5090107917785645
# Step step69000 Layer gpt_neox.layers.0.attention.dense.bias: Euclidean Distance = 0.4056159257888794
# Step step69000 Layer gpt_neox.layers.0.mlp.dense_h_to_4h.weight: Euclidean Distance = 21.095226287841797
# Step step69000 Layer gpt_neox.layers.0.mlp.dense_h_to_4h.bias: Euclidean Distance = 1.3582093715667725
# Step step69000 Layer gpt_neox.layers.0.mlp.dense_4h_to_h.weight: Euclidean Distance = 13.722626686096191
# Step step69000 Layer gpt_neox.layers.0.mlp.dense_4h_to_h.bias: Euclidean Distance = 0.4056159257888794
# Step step69000 Layer gpt_neox.layers.1.input_layernorm.weight: Euclidean Distance = 3.6352365016937256
# Step step69000 Layer gpt_neox.layers.1.input_layernorm.bias: Euclidean Distance = 0.5449157357215881
# Step step69000 Layer gpt_neox.layers.1.post_attention_layernorm.weight: Euclidean Distance = 1.7924630641937256
# Step step69000 Layer gpt_neox.layers.1.post_attention_layernorm.bias: Euclidean Distance = 0.9173592925071716
# Step step69000 Layer gpt_neox.layers.1.attention.query_key_value.weight: Euclidean Distance = 19.37213897705078
# Step step69000 Layer gpt_neox.layers.1.attention.query_key_value.bias: Euclidean Distance = 24.48932456970215
# Step step69000 Layer gpt_neox.layers.1.attention.dense.weight: Euclidean Distance = 7.405015468597412
# Step step69000 Layer gpt_neox.layers.1.attention.dense.bias: Euclidean Distance = 0.3043948709964752
# Step step69000 Layer gpt_neox.layers.1.mlp.dense_h_to_4h.weight: Euclidean Distance = 21.448577880859375
# Step step69000 Layer gpt_neox.layers.1.mlp.dense_h_to_4h.bias: Euclidean Distance = 1.6433221101760864
# Step step69000 Layer gpt_neox.layers.1.mlp.dense_4h_to_h.weight: Euclidean Distance = 14.293946266174316
# Step step69000 Layer gpt_neox.layers.1.mlp.dense_4h_to_h.bias: Euclidean Distance = 0.3043948709964752
# Step step69000 Layer gpt_neox.layers.2.input_layernorm.weight: Euclidean Distance = 3.105912208557129
# Step step69000 Layer gpt_neox.layers.2.input_layernorm.bias: Euclidean Distance = 0.8171645998954773
# Step step69000 Layer gpt_neox.layers.2.post_attention_layernorm.weight: Euclidean Distance = 0.9900786876678467
# Step step69000 Layer gpt_neox.layers.2.post_attention_layernorm.bias: Euclidean Distance = 0.7596496343612671
# Step step69000 Layer gpt_neox.layers.2.attention.query_key_value.weight: Euclidean Distance = 20.797746658325195
# Step step69000 Layer gpt_neox.layers.2.attention.query_key_value.bias: Euclidean Distance = 39.857810974121094
# Step step69000 Layer gpt_neox.layers.2.attention.dense.weight: Euclidean Distance = 8.977408409118652
# Step step69000 Layer gpt_neox.layers.2.attention.dense.bias: Euclidean Distance = 0.5025713443756104
# Step step69000 Layer gpt_neox.layers.2.mlp.dense_h_to_4h.weight: Euclidean Distance = 22.31835174560547
# Step step69000 Layer gpt_neox.layers.2.mlp.dense_h_to_4h.bias: Euclidean Distance = 2.2435152530670166
# Step step69000 Layer gpt_neox.layers.2.mlp.dense_4h_to_h.weight: Euclidean Distance = 17.078710556030273
# Step step69000 Layer gpt_neox.layers.2.mlp.dense_4h_to_h.bias: Euclidean Distance = 0.5025713443756104
# Step step69000 Layer gpt_neox.layers.3.input_layernorm.weight: Euclidean Distance = 6.331298828125
# Step step69000 Layer gpt_neox.layers.3.input_layernorm.bias: Euclidean Distance = 6.635000705718994
# Step step69000 Layer gpt_neox.layers.3.post_attention_layernorm.weight: Euclidean Distance = 4.730532646179199
# Step step69000 Layer gpt_neox.layers.3.post_attention_layernorm.bias: Euclidean Distance = 2.803785800933838
# Step step69000 Layer gpt_neox.layers.3.attention.query_key_value.weight: Euclidean Distance = 82.35862731933594
# Step step69000 Layer gpt_neox.layers.3.attention.query_key_value.bias: Euclidean Distance = 204.43983459472656
# Step step69000 Layer gpt_neox.layers.3.attention.dense.weight: Euclidean Distance = 12.265196800231934
# Step step69000 Layer gpt_neox.layers.3.attention.dense.bias: Euclidean Distance = 0.41337260603904724
# Step step69000 Layer gpt_neox.layers.3.mlp.dense_h_to_4h.weight: Euclidean Distance = 22.430601119995117
# Step step69000 Layer gpt_neox.layers.3.mlp.dense_h_to_4h.bias: Euclidean Distance = 2.465144157409668
# Step step69000 Layer gpt_neox.layers.3.mlp.dense_4h_to_h.weight: Euclidean Distance = 21.740644454956055
# Step step69000 Layer gpt_neox.layers.3.mlp.dense_4h_to_h.bias: Euclidean Distance = 0.41337260603904724
# Step step69000 Layer gpt_neox.layers.4.input_layernorm.weight: Euclidean Distance = 15.693741798400879
# Step step69000 Layer gpt_neox.layers.4.input_layernorm.bias: Euclidean Distance = 16.826261520385742
# Step step69000 Layer gpt_neox.layers.4.post_attention_layernorm.weight: Euclidean Distance = 7.212520599365234
# Step step69000 Layer gpt_neox.layers.4.post_attention_layernorm.bias: Euclidean Distance = 3.996058225631714
# Step step69000 Layer gpt_neox.layers.4.attention.query_key_value.weight: Euclidean Distance = 134.447265625
# Step step69000 Layer gpt_neox.layers.4.attention.query_key_value.bias: Euclidean Distance = 274.8622741699219
# Step step69000 Layer gpt_neox.layers.4.attention.dense.weight: Euclidean Distance = 21.340755462646484
# Step step69000 Layer gpt_neox.layers.4.attention.dense.bias: Euclidean Distance = 0.7509527206420898
# Step step69000 Layer gpt_neox.layers.4.mlp.dense_h_to_4h.weight: Euclidean Distance = 23.428646087646484
# Step step69000 Layer gpt_neox.layers.4.mlp.dense_h_to_4h.bias: Euclidean Distance = 2.5262742042541504
# Step step69000 Layer gpt_neox.layers.4.mlp.dense_4h_to_h.weight: Euclidean Distance = 22.384550094604492
# Step step69000 Layer gpt_neox.layers.4.mlp.dense_4h_to_h.bias: Euclidean Distance = 0.7509527206420898
# Step step69000 Layer gpt_neox.layers.5.input_layernorm.weight: Euclidean Distance = 20.86931037902832
# Step step69000 Layer gpt_neox.layers.5.input_layernorm.bias: Euclidean Distance = 3.8481216430664062
# Step step69000 Layer gpt_neox.layers.5.post_attention_layernorm.weight: Euclidean Distance = 5.202607154846191
# Step step69000 Layer gpt_neox.layers.5.post_attention_layernorm.bias: Euclidean Distance = 2.2603485584259033
# Step step69000 Layer gpt_neox.layers.5.attention.query_key_value.weight: Euclidean Distance = 68.48380279541016
# Step step69000 Layer gpt_neox.layers.5.attention.query_key_value.bias: Euclidean Distance = 223.4606170654297
# Step step69000 Layer gpt_neox.layers.5.attention.dense.weight: Euclidean Distance = 9.233643531799316
# Step step69000 Layer gpt_neox.layers.5.attention.dense.bias: Euclidean Distance = 0.7897031307220459
# Step step69000 Layer gpt_neox.layers.5.mlp.dense_h_to_4h.weight: Euclidean Distance = 21.207138061523438
# Step step69000 Layer gpt_neox.layers.5.mlp.dense_h_to_4h.bias: Euclidean Distance = 1.8741244077682495
# Step step69000 Layer gpt_neox.layers.5.mlp.dense_4h_to_h.weight: Euclidean Distance = 25.892526626586914
# Step step69000 Layer gpt_neox.layers.5.mlp.dense_4h_to_h.bias: Euclidean Distance = 0.7897031307220459
# Step step69000 Layer gpt_neox.final_layer_norm.weight: Euclidean Distance = 227.60845947265625
# Step step69000 Layer gpt_neox.final_layer_norm.bias: Euclidean Distance = 201.67404174804688
# Step step69000 Layer embed_out.weight: Euclidean Distance = 660.2181396484375
# pytorch_model.bin:   0%|          | 0.00/166M [00:00<?, ?B/s]
#  50%|█████████████████████████████████████████████████████████████████████████████████████▉                                                                                       | 71/143 [12:48<16:06, 13.43s/it]
# Step step73000 Layer gpt_neox.embed_in.weight: Euclidean Distance = 155.28036499023438
# Step step73000 Layer gpt_neox.layers.0.input_layernorm.weight: Euclidean Distance = 3.3782835006713867
# Step step73000 Layer gpt_neox.layers.0.input_layernorm.bias: Euclidean Distance = 1.3101263046264648
# Step step73000 Layer gpt_neox.layers.0.post_attention_layernorm.weight: Euclidean Distance = 1.6126105785369873
# Step step73000 Layer gpt_neox.layers.0.post_attention_layernorm.bias: Euclidean Distance = 0.4395098090171814
# Step step73000 Layer gpt_neox.layers.0.attention.query_key_value.weight: Euclidean Distance = 13.96826457977295
# Step step73000 Layer gpt_neox.layers.0.attention.query_key_value.bias: Euclidean Distance = 8.578335762023926
# Step step73000 Layer gpt_neox.layers.0.attention.dense.weight: Euclidean Distance = 6.112070560455322
# Step step73000 Layer gpt_neox.layers.0.attention.dense.bias: Euclidean Distance = 0.3720385730266571
# Step step73000 Layer gpt_neox.layers.0.mlp.dense_h_to_4h.weight: Euclidean Distance = 19.638389587402344
# Step step73000 Layer gpt_neox.layers.0.mlp.dense_h_to_4h.bias: Euclidean Distance = 1.2482069730758667
# Step step73000 Layer gpt_neox.layers.0.mlp.dense_4h_to_h.weight: Euclidean Distance = 12.812601089477539
# Step step73000 Layer gpt_neox.layers.0.mlp.dense_4h_to_h.bias: Euclidean Distance = 0.3720385730266571
# Step step73000 Layer gpt_neox.layers.1.input_layernorm.weight: Euclidean Distance = 3.3670504093170166
# Step step73000 Layer gpt_neox.layers.1.input_layernorm.bias: Euclidean Distance = 0.49263402819633484
# Step step73000 Layer gpt_neox.layers.1.post_attention_layernorm.weight: Euclidean Distance = 1.4947197437286377
# Step step73000 Layer gpt_neox.layers.1.post_attention_layernorm.bias: Euclidean Distance = 0.8469079732894897
# Step step73000 Layer gpt_neox.layers.1.attention.query_key_value.weight: Euclidean Distance = 18.192901611328125
# Step step73000 Layer gpt_neox.layers.1.attention.query_key_value.bias: Euclidean Distance = 18.124744415283203
# Step step73000 Layer gpt_neox.layers.1.attention.dense.weight: Euclidean Distance = 7.008277893066406
# Step step73000 Layer gpt_neox.layers.1.attention.dense.bias: Euclidean Distance = 0.2950457036495209
# Step step73000 Layer gpt_neox.layers.1.mlp.dense_h_to_4h.weight: Euclidean Distance = 20.185882568359375
# Step step73000 Layer gpt_neox.layers.1.mlp.dense_h_to_4h.bias: Euclidean Distance = 1.4058972597122192
# Step step73000 Layer gpt_neox.layers.1.mlp.dense_4h_to_h.weight: Euclidean Distance = 13.518302917480469
# Step step73000 Layer gpt_neox.layers.1.mlp.dense_4h_to_h.bias: Euclidean Distance = 0.2950457036495209
# Step step73000 Layer gpt_neox.layers.2.input_layernorm.weight: Euclidean Distance = 2.8417937755584717
# Step step73000 Layer gpt_neox.layers.2.input_layernorm.bias: Euclidean Distance = 0.7626940011978149
# Step step73000 Layer gpt_neox.layers.2.post_attention_layernorm.weight: Euclidean Distance = 0.8634381294250488
# Step step73000 Layer gpt_neox.layers.2.post_attention_layernorm.bias: Euclidean Distance = 0.7091232538223267
# Step step73000 Layer gpt_neox.layers.2.attention.query_key_value.weight: Euclidean Distance = 19.673280715942383
# Step step73000 Layer gpt_neox.layers.2.attention.query_key_value.bias: Euclidean Distance = 30.875642776489258
# Step step73000 Layer gpt_neox.layers.2.attention.dense.weight: Euclidean Distance = 8.481939315795898
# Step step73000 Layer gpt_neox.layers.2.attention.dense.bias: Euclidean Distance = 0.4952680468559265
# Step step73000 Layer gpt_neox.layers.2.mlp.dense_h_to_4h.weight: Euclidean Distance = 21.26533317565918
# Step step73000 Layer gpt_neox.layers.2.mlp.dense_h_to_4h.bias: Euclidean Distance = 1.9219151735305786
# Step step73000 Layer gpt_neox.layers.2.mlp.dense_4h_to_h.weight: Euclidean Distance = 16.203990936279297
# Step step73000 Layer gpt_neox.layers.2.mlp.dense_4h_to_h.bias: Euclidean Distance = 0.4952680468559265
# Step step73000 Layer gpt_neox.layers.3.input_layernorm.weight: Euclidean Distance = 5.476222515106201
# Step step73000 Layer gpt_neox.layers.3.input_layernorm.bias: Euclidean Distance = 6.202431678771973
# Step step73000 Layer gpt_neox.layers.3.post_attention_layernorm.weight: Euclidean Distance = 4.2210693359375
# Step step73000 Layer gpt_neox.layers.3.post_attention_layernorm.bias: Euclidean Distance = 2.9021637439727783
# Step step73000 Layer gpt_neox.layers.3.attention.query_key_value.weight: Euclidean Distance = 70.75592041015625
# Step step73000 Layer gpt_neox.layers.3.attention.query_key_value.bias: Euclidean Distance = 176.9962921142578
# Step step73000 Layer gpt_neox.layers.3.attention.dense.weight: Euclidean Distance = 11.309603691101074
# Step step73000 Layer gpt_neox.layers.3.attention.dense.bias: Euclidean Distance = 0.37504127621650696
# Step step73000 Layer gpt_neox.layers.3.mlp.dense_h_to_4h.weight: Euclidean Distance = 21.153060913085938
# Step step73000 Layer gpt_neox.layers.3.mlp.dense_h_to_4h.bias: Euclidean Distance = 2.244933605194092
# Step step73000 Layer gpt_neox.layers.3.mlp.dense_4h_to_h.weight: Euclidean Distance = 20.62352180480957
# Step step73000 Layer gpt_neox.layers.3.mlp.dense_4h_to_h.bias: Euclidean Distance = 0.37504127621650696
# Step step73000 Layer gpt_neox.layers.4.input_layernorm.weight: Euclidean Distance = 12.938494682312012
# Step step73000 Layer gpt_neox.layers.4.input_layernorm.bias: Euclidean Distance = 16.339618682861328
# Step step73000 Layer gpt_neox.layers.4.post_attention_layernorm.weight: Euclidean Distance = 6.16981840133667
# Step step73000 Layer gpt_neox.layers.4.post_attention_layernorm.bias: Euclidean Distance = 3.8130617141723633
# Step step73000 Layer gpt_neox.layers.4.attention.query_key_value.weight: Euclidean Distance = 123.3577880859375
# Step step73000 Layer gpt_neox.layers.4.attention.query_key_value.bias: Euclidean Distance = 238.1147003173828
# Step step73000 Layer gpt_neox.layers.4.attention.dense.weight: Euclidean Distance = 19.980337142944336
# Step step73000 Layer gpt_neox.layers.4.attention.dense.bias: Euclidean Distance = 0.6929873824119568
# Step step73000 Layer gpt_neox.layers.4.mlp.dense_h_to_4h.weight: Euclidean Distance = 22.22146224975586
# Step step73000 Layer gpt_neox.layers.4.mlp.dense_h_to_4h.bias: Euclidean Distance = 2.3865904808044434
# Step step73000 Layer gpt_neox.layers.4.mlp.dense_4h_to_h.weight: Euclidean Distance = 21.0870361328125
# Step step73000 Layer gpt_neox.layers.4.mlp.dense_4h_to_h.bias: Euclidean Distance = 0.6929873824119568
# Step step73000 Layer gpt_neox.layers.5.input_layernorm.weight: Euclidean Distance = 19.3572940826416
# Step step73000 Layer gpt_neox.layers.5.input_layernorm.bias: Euclidean Distance = 3.657622814178467
# Step step73000 Layer gpt_neox.layers.5.post_attention_layernorm.weight: Euclidean Distance = 4.785038948059082
# Step step73000 Layer gpt_neox.layers.5.post_attention_layernorm.bias: Euclidean Distance = 2.0289084911346436
# Step step73000 Layer gpt_neox.layers.5.attention.query_key_value.weight: Euclidean Distance = 63.86361312866211
# Step step73000 Layer gpt_neox.layers.5.attention.query_key_value.bias: Euclidean Distance = 190.93838500976562
# Step step73000 Layer gpt_neox.layers.5.attention.dense.weight: Euclidean Distance = 8.699068069458008
# Step step73000 Layer gpt_neox.layers.5.attention.dense.bias: Euclidean Distance = 0.7150243520736694
# Step step73000 Layer gpt_neox.layers.5.mlp.dense_h_to_4h.weight: Euclidean Distance = 19.958505630493164
# Step step73000 Layer gpt_neox.layers.5.mlp.dense_h_to_4h.bias: Euclidean Distance = 1.6905840635299683
# Step step73000 Layer gpt_neox.layers.5.mlp.dense_4h_to_h.weight: Euclidean Distance = 24.437171936035156
# Step step73000 Layer gpt_neox.layers.5.mlp.dense_4h_to_h.bias: Euclidean Distance = 0.7150243520736694
# Step step73000 Layer gpt_neox.final_layer_norm.weight: Euclidean Distance = 220.30026245117188
# Step step73000 Layer gpt_neox.final_layer_norm.bias: Euclidean Distance = 198.7793731689453
# Step step73000 Layer embed_out.weight: Euclidean Distance = 643.4456787109375
# pytorch_model.bin:   0%|          | 0.00/166M [00:00<?, ?B/s]

# %%
with open('pythia_70m_weight_dist.pickle', 'wb') as file:
    pickle.dump(step_dists, file)

# %%
# Distance form the last-epoch's layer's weights vs current-epcoh's

# %%
plot_data = []
for epoch, layers in step_dists.items():
    for layer, distance in layers.items():
        plot_data.append({'Epoch': int(epoch), 'Layer': layer, 'Distance': distance})

# Creating a DataFrame from the structured data
df = pd.DataFrame(plot_data)

# Sorting the DataFrame by Epoch for better plotting
df.sort_values(by='Epoch', inplace=True)

# Setting up the plot style
sns.set(style="whitegrid")

# Creating the plot
plt.figure(figsize=(30, 16))

# Plotting a line for each layer
for layer in list(ref_model_params.keys()):
    if "rotary_emb.inv_freq" not in layer:
        sns.lineplot(data=df[df['Layer'] == layer], x='Epoch', y='Distance', label=layer)

# Adding plot labels and title
plt.xlabel('Epoch')
plt.ylabel('Distance')
plt.title('Distance by Layer over Different Epochs')
plt.legend(title='Layers', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %%
# Distance form the last-epoch's layer's weights vs current-epcoh's (log-scale)

# %%
# Setting up the plot style
sns.set(style="whitegrid")

# Creating the plot
plt.figure(figsize=(30, 16))

# Dictionary to store slope data for each layer
slope_data = {'Layer': [], 'Slope': []}

# Plotting a line for each layer
for layer in list(ref_model_params.keys()):
    if ("rotary_emb.inv_freq" not in layer) and ("bias" not in layer):
        layer_data = df[df['Layer'] == layer]
        sns.lineplot(data=layer_data, x='Epoch', y='Distance', label=layer)

        # Calculating the slope using linear regression
        x = layer_data['Epoch']
        y = layer_data['Distance']
        slope, intercept = np.polyfit(x, y, 1)

        # Adding slope data to the dictionary
        slope_data['Layer'].append(layer)
        slope_data['Slope'].append(slope)

# Adding plot labels and title
plt.xlabel('Epoch')
plt.ylabel('Distance (log scale)')
plt.yscale('log')  # Set y-axis to logarithmic scale
plt.title('Distance by Layer over Different Epochs')
plt.legend(title='Layers', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %%
# Creating a DataFrame for the slope data
slope_df = pd.DataFrame(slope_data)

# Displaying the slope data
print("Slope Data:")
print(slope_df)
